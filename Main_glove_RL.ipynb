# %%
from __future__ import unicode_literals, print_function, division
from io import open
import unicodedata
import string
import re
import random
import pickle
import numpy as np
import scipy.spatial
# %matplotlib inline

import torch
import torch.nn as nn
from torch.autograd import Variable
from torch import optim
import torch.nn.functional as F

# GLOVE Vectors
import torchtext.vocab as vocab

use_cuda = torch.cuda.is_available()
print(" I have a GPU? ", use_cuda)
# Out:
#  I have a GPU?  True

# %% [markdown]
# ## Installing torchtext
#
# The torchtext package is not currently on the PIP or Conda package managers, but it's easy to install manually:
# may require sudo.
#
# ```
# git clone https://github.com/pytorch/text pytorch-text
# cd pytorch-text
# python setup.py install
# ```

# %%
glove = vocab.GloVe(name='6B', dim=50)

print('Loaded {} words'.format(len(glove.itos)))
# Out:
# Loaded 400000 words

# %% [markdown]
# The returned `GloVe` object includes attributes:
# - `stoi` _string-to-index_ returns a dictionary of words to indexes
# - `itos` _index-to-string_ returns an array of words by index
# - `vectors` returns the actual vectors. To get a word vector get the index to get the vector:

# %%
glove.vectors[0][:5]
# Out:
#  0.4180
#  0.2497
# -0.4124
#  0.1217
#  0.3453
# [torch.FloatTensor of size 5]

# %% [markdown]
# ## Can skip the preprocessign step and just load the pickle file

# %%
class Lang:
    
    def __init__(self, name):
        
        '''
        Store the string token to index token
        mapping in the word2index and index2word
        dictionaries. 
        '''
        
        self.name = name
        self.trimmed = False # gets changed to True first time Lang.trim(min_count) is called
        self.word2index = {}
        self.word2count = {}
        self.index2word = {0: "<PAD>", 1: "<SOS>", 2: "<EOS>", 3: "<UNK>"}
        self.n_words = len(self.index2word) # Count default tokens
        self.num_nonwordtokens = len(self.index2word)
        self.PAD_token = 0
        self.SOS_token = 1
        self.EOS_token = 2
        self.UNK_token = 3

    def index_sentence(self, sentence):
        '''
        Absorbs a sentence string into the token dictionary
        one word at a time using the index_word function
        increments the word count dictionary as well
        '''
        for word in sentence.split(' '):
            self.index_word(word)

    def index_word(self, word):
        if word not in self.word2index:
            self.word2index[word] = self.n_words
            self.word2count[word] = 1
            self.index2word[self.n_words] = word
            self.n_words += 1
        else:
            self.word2count[word] += 1

    
    def trim(self, min_count):
        '''
        Removes words from our 3 dictionaries that
        are below a certain count threshold (min_count)
        '''
        if self.trimmed: return
        self.trimmed = True
        
        keep_words = []
        
        for k, v in self.word2count.items():
            if v >= min_count:
                keep_words.append(k)

        print('keep_words %s / %s = %.4f' % (
            len(keep_words), len(self.word2index), len(keep_words) / len(self.word2index)
        ))

        # Reinitialize dictionaries
        self.word2index = {}
        self.word2count = {}
        self.index2word = {0: "<PAD>", 1: "<SOS>", 2: "<EOS>", 3: "<UNK>"}
        self.n_words = len(self.index2word) # Count default tokens
        self.num_nonwordtokens = len(self.index2word)
        self.PAD_token = 0
        self.SOS_token = 1
        self.EOS_token = 2
        self.UNK_token = 3

        for word in keep_words:
            self.index_word(word)
            
    def unicode_to_ascii(self, s):
        return ''.join(
            c for c in unicodedata.normalize('NFD', s)
            if unicodedata.category(c) != 'Mn')
            
    def normalize_string(self, s):
        s = self.unicode_to_ascii(s.lower().strip())
        s = re.sub(r"([.!?])", r" \1", s)
        s = re.sub(r"[^a-zA-Z.!?]+", r" ", s)
        s = re.sub("newlinechar", "", s)
        s = s.replace("'","")
        s = s.replace(".","")
        s = s.replace("n t ","nt ")
        s = s.replace("i m ","im ")
        s = s.replace("t s ","ts ")
        s = s.replace(" s ","s ")
        s = s.replace(" re "," are ")
        s = s.replace("i ve ","ive ")
        s = s.replace(" d ","d ")
        s = ' '.join(s.split())
        return s

    def filterPair(self, p, max_sent_len, min_sent_len):
        
        '''
        Your Preferences here
        '''

        return len(p[0].split(' ')) < max_sent_len and \
               len(p[1].split(' ')) < max_sent_len and \
               len(p[1].split(' ')) > min_sent_len and \
               "https://" not in p[1] 

    
    def make_pairs(self, path_to_tab_sep_dialogue, 
                   max_sent_len = 20, min_sent_len = 4):

        print("making final_pairs list ...")
        lines = open(path_to_tab_sep_dialogue).read().strip().split('\n')
        
        final_pairs = []
        i = 0
        for l in lines:
            
            pair = [self.normalize_string(sentence) for sentence in l.split('\t')]
            
            if self.filterPair(pair,max_sent_len, min_sent_len):
                
                filtered_pair = []
                
                for sentence in pair:

                    self.index_sentence(sentence)
                    filtered_pair.append(sentence)
                  
                final_pairs.append(filtered_pair)
        print("number of pairs", len(final_pairs))
        return final_pairs
    
    def tokens2glove(self, min_word_count,glove, mbed_dim = 50):
    
        print("trimming...")    
        self.trim(min_word_count)
        
        if glove is None:
            glove = vocab.GloVe(name='6B', dim=embed_dim)
            print('Loaded {} words'.format(len(glove.itos)))
        else:
            embed_dim = glove.vectors.size(1)
                    
        print("building embedding from glove...")
        embedding = np.zeros((len(self.index2word), embed_dim)).astype(np.float32)
        for i in range(self.num_nonwordtokens):
            embedding[i,:] = np.random.uniform(-1,1,embed_dim).astype(np.float32)
        for i in range(self.num_nonwordtokens,len(self.index2word)):
            if self.index2word[i] in glove.stoi:
                embedding[i,:] = glove.vectors[glove.stoi[self.index2word[i]]]
            else:
                embedding[i,:] = np.random.uniform(-1,1,embed_dim).astype(np.float32)
        
        return self.index2word, self.word2index, embedding, self.n_words #torch.from_numpy(embeddings).float()

# %%
MAX_SENT_LENGTH = 20
lang = Lang("chat")

# %%
final_pairs = lang.make_pairs("../data/input-output.txt", max_sent_len = MAX_SENT_LENGTH, 
                              min_sent_len = 3)
# Out:
# making final_pairs list ...
# number of pairs 317106

# %%
index2word, word2index, embedding, vocab_size = lang.tokens2glove(5,glove)
# Out:
# trimming...
# keep_words 22348 / 52457 = 0.4260
# building embedding from glove...

# %%
final_pairs
# Out:
# [['negro what the hell you doing to my woman ?', 'i dont know !'],
#  ['shut up miss henried ! i tol ya b fore !',
#   'this is a travesty ! captain rhodes is'],
#  ['objection',
#   'sustained yes the witness will confine his testimony to review of the hospital records'],
#  ['whats wrong skipper ?',
#   'what i was afraid would happen the stuff we passed through that looked like seaweed'],
#  ['what ?', 'you just burned the desk'],
#  ['she shore dont look prosperous want to go somewheres else ?',
#   'on a gallon a gas ? lets set up the tent maybe i can fix us up some stew'],
#  ['i i think i understand i think i get it',
#   'no what you are feeling is premature enlightenment'],
#  ['look maybe id better talk to dick is he around ?', 'dick ? dick who ?'],
#  ['a married lady', 'with the paper to prove it'],
#  ['they ll be back he had to go in for a urinalysis',
#   'would you care for a drink while you are waiting ? i can put it on the underhill bill'],
#  ['would you care for a drink while you are waiting ? i can put it on the underhill bill',
#   'great i ll have a bloody mary and a steak sandwich'],
#  ['i didnt', 'i put everything in my room my teddy bear is joining us'],
#  ['hi oh hi hi', 'well bye she laughs and backs up slowly toward the door'],
#  ['well bye she laughs and backs up slowly toward the door',
#   'you you play very well'],
#  ['the night is a tunnel a hole into tomorrow if we are to have a tomorrow',
#   'remember walk without rhythm and we wont attract a worm it ll go to the thumper'],
#  ['when the stiffs an irish the cops take it kinda personal',
#   'cant we get a couple whores over ?'],
#  ['cant we get a couple whores over ?', 'you aint even a man yet'],
#  ['what is this ? dont be stupid man',
#   'first you question my integrity then you call me stupid that hurts son'],
#  ['hello may i speak to mitch brenner please ? yes i ll wait',
#   'insist on making it difficult for life to survive on this planet if it werent for birds'],
#  ['at first', 'you got anybody wick ?'],
#  ['do you ?',
#   'i know that this was probably a great white shark car cadon caradan'],
#  ['if i ever loved narcissus it wasnt like you want',
#   'but i get what i want always dont i ?'],
#  ['do you mind this is like the most important moment of my whole life',
#   'forget it jen ive waited a year for this'],
#  ['and look what you ve done to mr bigglesworth !',
#   'we could not anticipate feline complications due to the reanimation process emdash'],
#  ['i gotta figure some way out of this thing !',
#   'the elevators are still runnin'],
#  ['my wife ?', 'yeah uh they brung her to the county jail uh'],
#  ['yes the big celebration of my mandatory retirement birthday you are an honored guest eddie',
#   'im going to stick it out here we still have a shot'],
#  ['the uh cynthia branson estate was worth how much ? because her family',
#   'what family ? we never heard from them i sold her house for them made them money'],
#  ['listen i want to talk to you about the prom',
#   'you know the deal i cant go if kat doesnt go'],
#  ['it aint even three years we been married',
#   'three years ago i said them very words no and good'],
#  ['twenty percent', 'fine i want half plus the release of the family'],
#  ['non e questo il luogo per le vostre conversazioni private !',
#   'a ragione a ragione'],
#  ['a ragione a ragione', 'hmm c e questa'],
#  ['you guys are crazy you know that ? i mean you guys are really nuts',
#   'hes getting married and we are nuts !'],
#  ['hes getting married and we are nuts !',
#   'its all right hey its all right we ll be right here right with you'],
#  ['i presume youd prefer handling the delivery',
#   'all i said was i dont want to perform abortions i have no argument with you performing them'],
#  ['that looks like fifty thousand dollars from here', 'this is your money ?'],
#  ['this is your money ?', 'if i were to tell you no it isnt'],
#  ['of course', 'it was not inspired by circumstance'],
#  ['it was not inspired by circumstance', 'no it most certainly was not'],
#  ['jack you are wrong', 'good afternoon mr brumby carter exits'],
#  ['next stop', 'pizza planet ! yeah ! ! !'],
#  ['hi daddy', 'well what happened to you ?'],
#  ['well what happened to you ?', 'i won a flower'],
#  ['please paul why do we have to go to the roof ?',
#   'its alright this is the only place i can find some peace'],
#  ['no why ?', 'you sure hes not italian ?'],
#  ['you sure hes not italian ?', 'hes black ok ?'],
#  ['gatling ! they ve got a gatling !',
#   'dammit this stopped being fun about two years ago !'],
#  ['do i ?', 'it happens take it easy'],
#  ['whats up with you ?', 'me ? nothing tell me more about the job'],
#  ['last night you were talking to someone in the corridor',
#   'you must have been dreaming'],
#  ['dont hold back on us max we need all the help we can get',
#   'fucked up chromosomes man think about it their parents all dropped acid in the sixties'],
#  ['fucked up chromosomes man think about it their parents all dropped acid in the sixties',
#   'it beats dr simms theory she thinks its nothing but sex drugs and rock roll'],
#  ['as you will', 'you must look at my face and not at the floor'],
#  ['it has been taken freylag and all his people slaughtered',
#   'it is only a few weeks and already half our strong places have fallen'],
#  ['and how much are these ?',
#   'seventy eight dollars the girl who rolled these was probably wearing panties'],
#  ['im very sorry i',
#   'you are very sorry you passive aggressive son of a bitch can we replace him ?'],
#  ['its something ive always wanted to do',
#   'you actually could make breaking and entering into a new career so what are you doing here ?'],
#  ['do you like this hotel ?', 'yes i do i love it dont you ?'],
#  ['sorry', 'so hows college ?'],
#  ['well i think its getting late good night ninotchka',
#   'thank you for a wonderful dinner'],
#  ['sir august merryweather why are we seeing him first ?',
#   'as per mothers instructions'],
#  ['the goddamn smell is always the same',
#   'are you going to be able to sleep ?'],
#  ['are you going to be able to sleep ?',
#   'yeah i think so mike ! keep it down for chrissake !'],
#  ['dont explain', 'how long you going away for ?'],
#  ['shoot him nicky not that we really mean it but where does he live ?',
#   'keep going west last building before the river'],
#  ['keep going west last building before the river', 'how do you eknow'],
#  ['oh uh my stepmom took me to the doctor yesterday and they said i was twelve weeks',
#   'oh thats marvelous so you are almost into your second trimester then ?'],
#  ['oh thats marvelous so you are almost into your second trimester then ?',
#   'yeah apparently im having it on may'],
#  ['you think so ?',
#   'yeah ive always hated that kid he used to eat glue in like seventh grade'],
#  ['no thanks', 'you are my mothers hairdresser ?'],
#  ['you are my mothers hairdresser ?', 'i do her hair yeah'],
#  ['well',
#   'i mean you dont exactly have the build for a football i mean no offense'],
#  ['i mean you dont exactly have the build for a football i mean no offense',
#   'no you are right'],
#  ['its already planned mike its going to cost at the free clinic',
#   'doesnt sound free to me so you want me to pay for it ?'],
#  ['doesnt sound free to me so you want me to pay for it ?',
#   'half okay ? seventy five dollars and a ride to the clinic'],
#  ['annette ?',
#   'devastated beyond repair i doubt she ll ever trust a man again'],
#  ['dig the square wardrobe !', 'yeah so wheres the high school ?'],
#  ['yeah so wheres the high school ?',
#   'university and th want to carry my books ?'],
#  ['whats the matter boys ? is my slip showing ?',
#   'i ll say it is you spilled a little borscht on it'],
#  ['miss kubelik you shouldnt be out of bed',
#   'i didnt know i had no idea this was your apartment'],
#  ['i didnt know i had no idea this was your apartment', 'let me help you'],
#  ['gus if theres anything i hate its greed',
#   'greed ! let me tell you something'],
#  ['you ve been following me ?',
#   'her its an obvious move im building a case against her remember ?'],
#  ['superman ! the', 'really lois we ve got to stop meeting this'],
#  ['really lois we ve got to stop meeting this',
#   'the bomb ! its in there ! any second now its'],
#  ['he does it right in front of him',
#   'its getting better and better keep going'],
#  ['i think someone broke into my house', 'no shit ? !'],
#  ['how did you get onto doom ?',
#   'marvin told me doom was after his land ne was afraid thats why he brought me his will'],
#  ['marvin told me doom was after his land ne was afraid thats why he brought me his will',
#   'so where is it ?'],
#  ['im searching for patterns in the noise thats all order in the chaos im practicing listening',
#   'the point is this isnt just scientific inquiry anymore its turned into some kind of personal obsession'],
#  ['you are hot tonight honey but be quiet ! shhhh ! the kids !',
#   'yeah ! oohhhh ! get it !'],
#  ['yeah ! oohhhh ! get it !', 'ooh honey im ready ! now ! now !'],
#  ['im just giving you the truth there was a time when william parrish liked the truth',
#   'i think its time you went home drew'],
#  ['i know but since we are talking i thought id mention it',
#   'we are not talking you are talking and doing too damn much of it if you ask me'],
#  ['two hundred and fifty dollars you owe met', 'you found the leopard !'],
#  ['field trip ?', 'lunch hour my next class isnt till nine thirty'],
#  ['it surprises me it really does',
#   'any person who spends a significant amount of time with me finds me disagreeable just ask your husband'],
#  ['its muscles are locked', 'oh jesus ! !'],
#  ['im really sorry',
#   'bullshit ! you hate us if you had half a chance youd feed us to them !'],
#  ['i hear they need a new lieutenant want the job ?',
#   'i ll take it until i get killed or you find someone better'],
#  ['good girl', 'and what do you do wh'],
#  ['do you realize what i can create with a single strand of supermans hair !',
#   'a toupee that flies ?'],
#  ['we are hungry do you have anything to eat ?', 'anything to eat ?'],
#  ['clear', 'clear meadows that shits dead'],
#  ['a giant hydraulically operated microscope that explodes ? or maybe just someone who hates scientists',
#   'then why kidnap them ? why not just kill them ?'],
#  ['then why kidnap them ? why not just kill them ?',
#   'ay theres the rub take a look at this file on professor morton quite a brilliant fellow metallurgy'],
#  ['you okay ?',
#   'yeah im just gettin old i cant smoke or laugh now it seems without coughing'],
#  ['no no dont cry at the beginning of the date', 'oh knock it off !'],
#  ['say whos putting up this dough ?',
#   'feller runs the chronicle heres the speech you makeand its all written out for you'],
#  ['all right now theres milk and cookies in the refrigerator go to bed right after falcon crest',
#   'ed we are so glad you could come over at the last minute and judge our little beauty pageant'],
#  ['why not ?', 'i just cant okay ?'],
#  ['not exactly', 'they were vampires werent they ?'],
#  ['would you like us to notify anyone for you ?',
#   'no the old man died and louise left'],
#  ['oh harry im so proud of you making a real friend',
#   'is it okay if he spends the night ?'],
#  ['is it okay if he spends the night ?', 'lloyd did you ask your parents ?'],
#  ['thanks but i ll take the bus i do it all the time',
#   'dandridge is a condescending prick ride with me it would be because i want you to'],
#  ['i dont know',
#   'im sure he wont be angry once he realizes how concerned you are about him'],
#  ['its over !', 'what is your wifes picture doing by the side of your'],
#  ['what is your wifes picture doing by the side of your',
#   'what is that to you ?'],
#  ['yes why not', 'ada says you are doing well with the piano ?'],
#  ['oh my god ! i almost forgot i got you a meeting with the admissions guy from dartmouth !',
#   'what ! but i wasnt even going to go to college'],
#  ['we cant', 'any word from him ?'],
#  ['i didnt know you were out', 'did it seem short to you ?'],
#  ['did it seem short to you ?',
#   'thats all over as far as im concerned emmett im satisfied'],
#  ['huh ?', 'i just saw a man walk out of your room'],
#  ['okay i know you ve been scared now you want to scare someone',
#   'does that scare you ?'],
#  ['whats your name ?', 'me ? willie long'],
#  ['me ? willie long', 'what are you in for willie ?'],
#  ['holy smoke ! a half a heelot !',
#   'there you are boss just like you ordered symbols of the little people'],
#  ['camels same as me guess both my mama and my daddy died of smoke or alcohol related illness',
#   'gee sailor im sorry honey i never would have guessed it'],
#  ['sailor aint a boy no more mama', 'dont mean him its pace concerns me'],
#  ['dont mean him its pace concerns me', 'really mama i gotta go'],
#  ['hejira', 'and so now you are off to glades'],
#  ['could buy a lot of steaks dollars',
#   'i cant be positive that it was used for the break in but people sure are worried'],
#  ['mr peterson are you sure mama wrote all this ?',
#   'well it was notarized and witnessed by a mrs lucy delaney maybe you can ask her'],
#  ['well it was notarized and witnessed by a mrs lucy delaney maybe you can ask her',
#   'who the hell is lucy delaney ?'],
#  ['we didnt sign on for this shit fuck ! this shit is intense i need to call my agent',
#   'just shut up and do what they say they are gonna kill us if we dont ian'],
#  ['of course', 'so whats her name ?'],
#  ['so whats her name ?', 'you know i got a lot more than one'],
#  ['is it set ?', 'primed to go off right over his head officer'],
#  ['hows it going ?',
#   'its going fine the quiet riot and me are swapping trade secrets'],
#  ['oh harry you are so funny now i have something thats kind of delicate',
#   'oh you want to talk about your delicates ?'],
#  ['oh you want to talk about your delicates ?',
#   'are you trying to be funny ? or are you actually are re special'],
#  ['no of course he lives there would i point it out to you if he didnt ?',
#   'that w as p bastard'],
#  ['that w as p bastard', 'you are intolerable today'],
#  ['just like that ?',
#   'just like that load up the lincoln point it west stop when we hit the fucking ocean'],
#  ['water mains usually go in the winter its august st',
#   'tell you what reminds me of life in the delta'],
#  ['so what did you want ? i think we understand each other no ?',
#   'you dont understand me'],
#  ['you dont understand me', 'you dont understand you either'],
#  ['hello ?',
#   'where are you ? you are driving me crazy waiting like this i want you in me now !'],
#  ['how did you get into the business ?',
#   'the same way everyone does the government the agency'],
#  ['i dive in search of god if i go deep enough im going to find him',
#   'a little you think its the same for jacques ?'],
#  ['good morning', 'thats all the gusta you can musta ? i said good morning !'],
#  ['do you have any more of these deli cious cookies ?',
#   'anything else mr black ? how about some water ?'],
#  ['you broke a dozen training rules back there before i lost count',
#   'ive had it just because they pay me like a baby sitter doesnt mean im gonna be one'],
#  ['ive had it just because they pay me like a baby sitter doesnt mean im gonna be one',
#   'shes a trainee just like the others why are you coming down so hard ?'],
#  ['when i gave you my gun and you almost shot me',
#   'maybe you should see a psychiatrist'],
#  ['i cant say that !', 'no you can tell him to get on the fucking phone !'],
#  ['i ll fuckin give it to him ! we ll go down there',
#   'you dont understand he wants all the money that is in your bank'],
#  ['you dont understand he wants all the money that is in your bank',
#   'ive got eight hundred pounds oh jesus'],
#  ['ask not for whom the telephone rings', 'no please ! i beg you'],
#  ['no please ! i beg you', 'walk over to the window'],
#  ['or ?', 'they revoke our flight status'],
#  ['they revoke our flight status', 'oh i see teamwork'],
#  ['the dishes ?', 'i mean after that ?'],
#  ['ah did you hear that ? spooky loved you',
#   'yeah pretty gross hurry we ve got work to do'],
#  ['i might', 'nice car how much did you pay for it ?'],
#  ['no it wont do', 'what wont do ?'],
#  ['what wont do ?', 'you are much too human'],
#  ['he ll try to finish his experiment',
#   'and blow up the universe just to prove hes right ? bit egotistical isnt it ?'],
#  ['no', 'did your husband strike or physically abuse his child in any way ?'],
#  ['nothing', 'then whats going on ?'],
#  ['then whats going on ?', 'i went to the doctor today'],
#  ['calm down you are not', 'calm down look at this look at him !'],
#  ['what did he do this time ?',
#   'y know all those pictures he has hanging on the wall of fame ?'],
#  ['you are too young to be studying criminal behavior its making you obsessive',
#   'she is kicking you out'],
#  ['if they dont tell me what i need to know', 'doesnt it get tiring ?'],
#  ['you lied',
#   'i equivocated but you are not their big worry at present its dr darling hes disappeared'],
#  ['shes tired', 'its bad news when you cant even bribe kids'],
#  ['its bad news when you cant even bribe kids',
#   'i want you so bad she ll be asleep soon maybe we could do it quietly under the sheets'],
#  ['just kidding',
#   'gabe ? wait til i get over there tie the rope so i can come across'],
#  ['ethan hunt', 'well ethan hunt what is it you want to talk to me about ?'],
#  ['shouldnt they be there by now ? whats taking them so long ? !',
#   'hey these guys are professionals they are the best c mon they are not lying down on the job'],
#  ['no dollar', 'hey give rocky a dime'],
#  ['its been a while', 'wheres the dog ?'],
#  ['wheres the dog ?', 'appreciate the loan im good for it'],
#  ['huh let me think', 'you sure you didnt say anything to maya ?'],
#  ['crabs would get most of the newborns before they made it to the sea huh ?',
#   'yeah but not now these will all make it guaranteed'],
#  ['yeah but not now these will all make it guaranteed',
#   'whatever i say you ll take him away wont you ?'],
#  ['listen harry i didnt believe that', 'its good to see you holly'],
#  ['what are you talking about ?', 'think what you have time to think lester'],
#  ['yes ?',
#   'mrs stanwyk i hate to disturb you tom underhill here im a new member'],
#  ['it may be that i could confer with my colleagues on this and get back to you',
#   'would you doctor ? that would be so kind'],
#  ['whats this ?', 'why dont you open it and find out ?'],
#  ['why dont you open it and find out ?',
#   'jesus god auggie theres money in here'],
#  ['tis the season convict', 'cant be attracting attention right ?'],
#  ['cant be attracting attention right ?',
#   'what we walking in there and delivering toys ?'],
#  ['and im arranging deportation papers',
#   'yes yes thats eminently fair of you'],
#  ['yes yes thats eminently fair of you',
#   'and im bringing you in and locking you up until you tell me'],
#  ['scalping to a funeral you are a pretty sleazy guy',
#   'thanks you interested its festival seating so'],
#  ['you have no sick time frank no time of any kind everyone knows that',
#   'take me back put me to bed i surrender we ve done enough damage tonight'],
#  ['sure !', 'of course honey come in bed with us come on'],
#  ['i added air conditioning put in the pool made all those pillows by hand',
#   'yeah ? i should learn to do stuff like that they make the place feel real homey'],
#  ['that is so sad',
#   'i know like five chickens had to die just so she could look that stupid'],
#  ['unfortunately yes', 'but you see thats okay wayne'],
#  ['we are half a million off', 'fuck it im not counting it again'],
#  ['fuck it im not counting it again',
#   'weight it if its sixty pounds its three if its fifty its two point five'],
#  ['mary mary im sorry ive got to go', 'come on george lets hurry'],
#  ['come on george lets hurry', 'did you get a doctor ?'],
#  ['and if i were in the comoros in the indian ocean where would you be ?',
#   'a few more moments still in this business then id find you'],
#  ['saturday night yes sir have a pleasant journey !',
#   'darling ! you will be careful ! ?'],
#  ['well hes a good soldier', 'i didnt mean that as a compliment'],
#  ['how sweet', 'my timing always was lousy'],
#  ['why else would you send off for me ? if you just wanted sex just go to a prostitute',
#   'well as it turns out i did'],
#  ['who is this paxcow ? is he like the boogeyman ?',
#   'hes a ghost but hes a good ghost'],
#  ['hes a ghost but hes a good ghost',
#   'there are no ghosts ellie i want you to go to sleep and forget all this nonsense'],
#  ['wed better go outside quickly', 'is there any chance ?'],
#  ['is there any chance ?', 'i guess theres always a chance'],
#  ['leave me alone !',
#   'you ve got to trust me it sounds silly but i know we were meant to meet'],
#  ['no just just give him give him ten thats it ten i ll be right down',
#   'hes gonna come up with ten thousand just the way you wanted'],
#  ['so talk', 'we think we got a rat in the house'],
#  ['no', 'of the woman in the mirror would you know her if you saw her ?'],
#  ['mazel tov !', 'hello mazel tov ! a boojee boojee boojee boo'],
#  ['hello mazel tov ! a boojee boojee boojee boo', 'im not finished yet mom'],
#  ['u you u put it in there', 'i may have said some thing i dont recall'],
#  ['i dont know what you are talking about im just driving',
#   'look what im doing is none of your business'],
#  ['look what im doing is none of your business',
#   'is alan baer the game ? is that what this is ?'],
#  ['yep', 'you didnt even hafta say it i know the woman'],
#  ['ssh hes great', 'peggy sues still stuck on treble without a cause'],
#  ['peggy sues still stuck on treble without a cause',
#   'i thought i knew everything about him'],
#  ['im adjusting okay', 'and your new apartment ?'],
#  ['why does this sound so familiar ?',
#   'assault on voltareck iii episode i think'],
#  ['assault on voltareck iii episode i think', 'we are doing episode ?'],
#  ['wow !', 'what just happened ?'],
#  ['what just happened ?', 'are you okay ?'],
#  ['arthur', 'lancelot i will save you dont die'],
#  ['lancelot i will save you dont die',
#   'my salvation is to die a knight of the round table'],
#  ['where is she ?', 'i can hear her oh mother of god i can hear her'],
#  ['i can hear her oh mother of god i can hear her', 'casey ! casey !'],
#  ['you bet we all cant be such modern people',
#   'come on mark mark ah hell why not i ll get the maid to write the essays'],
#  ['what ?', 'could ya take off that hat'],
#  ['its my own way it works for me i dont care about the rest of that stuff',
#   'then why are you here ?'],
#  ['your mothers murder was last years hottest court case somebody was gonna write a book about it',
#   'and it had to be you with all your lies and bullshit theories'],
#  ['no edgar allen', 'the furniture guy ?'],
#  ['you all right ethan ?', 'huh ? sure im all right'],
#  ['huh ? sure im all right',
#   'say ! what happened to your blanket ? lose it ?'],
#  ['the dirty yellow rat bastard',
#   'dont push it you way ahead you back on top that boy loves you man'],
#  ['dont push it you way ahead you back on top that boy loves you man',
#   'what you say ?'],
#  ['excuse me is this the buildings and grounds office ?',
#   'yeah can i help you ?'],
#  ['taiwan',
#   'not that i would know but you look like you are really good at it'],
#  ['you are not in a very good mood', 'you dont miss a thing'],
#  ['you living together ?', 'shes back in jersey going to graduate school'],
#  ['shes back in jersey going to graduate school', 'explain how that works'],
#  ['his name is chuckie roeder but somethings very weird',
#   'you found his mugshot ?'],
#  ['what the hell good is hooker to ya ?', 'hes gonna set up gondorff for us'],
#  ['damn', 'almost got me in billings i saw you there shooting at me'],
#  ['almost got me in billings i saw you there shooting at me',
#   'i went myself to oversee the operation didnt help much'],
#  ['yeah yeah right what the fuck are doing ? what the fuck are you doing in my house ?',
#   'dont yell honey please dont go crazy'],
#  ['dont yell honey please dont go crazy',
#   'im not crazy dont you tell me im crazy'],
#  ['so how did you find out i didnt do it ?',
#   'i didnt i just realized i already knew'],
#  ['i know ive felt it', 'im weak soon i ll need to feed'],
#  ['well just dont forget your old friends when you are rich and famous',
#   'are you kidding ? you guys ll he running this joint by then'],
#  ['you are anya rosson arent you ? ive heard of you back in new york',
#   'sorry i cant return the compliment'],
#  ['now what ?', 'ive never met anyone like you'],
#  ['nick hes fine hes in a hospital and they are fixing him up',
#   'you talk to him ?'],
#  ['you talk to him ?', 'oh sure twice a day'],
#  ['wed like to ask you some questions about daniel zavitz',
#   'who u are u you people ?'],
#  ['who u are u you people ?', 'im an investigator with pro tech security'],
#  ['the white reflects the sun it keeps you cooler thats why they wear them',
#   'think the iraqis killed them all ?'],
#  ['think the iraqis killed them all ?',
#   'probably shot a few scattered the rest murderers'],
#  ['nah not now i wanna wait i dont feel right',
#   'im tellin you she ll be there i know she ll be there'],
#  ['im tellin you she ll be there i know she ll be there',
#   'cause i wanna catch her alone'],
#  ['goodbye', 'you didnt deserve me john buckingham'],
#  ['i dont know why i just couldnt help it',
#   'but sooner or later we ve got to end this relationship and its better to do it right now'],
#  ['you lent it to me in like tenth grade',
#   'ive been looking all over for this'],
#  ['ive been looking all over for this', 'look at how cute i am !'],
#  ['whats bothering you madison ?',
#   'the pain is getting worse i need more aspirin'],
#  ['the pain is getting worse i need more aspirin',
#   'i cant give you anymore i ll talk to the doctor'],
#  ['you dont understand the wedding bands the wedding bands are in my wallet',
#   'okay so they were in your wallet and you left your wallet somewhere some bar christine ll understand'],
#  ['get your things',
#   'hiroshima ! shes going with us ? are you out of your mind'],
#  ['youd think they ve never seen a new toy before',
#   'well sure look at him hes got more gadgets on him then a swiss army knife'],
#  ['bob are you making friends with this man ?',
#   'im just bragging about how great you are im the luckiest man alive'],
#  ['have ya been to the celebrity room before ? with other uh clients ?',
#   'i dont think so its nice'],
#  ['i dont think so its nice',
#   'yeah well it depends on the artist you know jose feliciano ya got no complaints waiter !'],
#  ['i just saw joe hes here', 'well you dont have to be so dramatic about it'],
#  ['no', 'sorry ned guess i wasted your time see ya kid !'],
#  ['sorry ned guess i wasted your time see ya kid !',
#   'you are goin back with him ?'],
#  ['especially now', 'so ive been thinking a lot'],
#  ['nah you go on', 'i have to talk to evelyn and i want you to meet her'],
#  ['i have to talk to evelyn and i want you to meet her',
#   'some other time i dont feel like a party'],
#  ['bravo !',
#   'but i dont have that any more all thats left for me now is the room upstairs'],
#  ['i thought i saw', 'it looks like a branch'],
#  ['why ?', 'just you could look very heavy'],
#  ['just you could look very heavy', 'dont make conversation with me'],
#  ['he wrote this thing about his dick once and he read it in front of the whole class',
#   'id love to read that'],
#  ['you think he got my license plates ?', 'he looked too shaken up'],
#  ['what about ids ?', 'one to seven deal the face cards'],
#  ['all the facts you need are right in front of you',
#   'gimme a minute here i think ive got it'],
#  ['it was an earthquake and it was dark i have no idea',
#   'these look quite fresh'],
#  ['send him away', 'send him ? ma i cant its just come out here please i'],
#  ['mom not now ! i i dont know what to do',
#   'yes you do you have to go rescue all those people'],
#  ['yes you do you have to go rescue all those people',
#   'but im not a hero im nobodys heroine im nothing you ve said so yourself many times'],
#  ['im going alone this could be dangerous', 'okay my sweet good night'],
#  ['hed give me a job', 'he would take you on yes'],
#  ['how wonderful darling what does that mean for you ?',
#   'i ll be running it three days a week and'],
#  ['i ll be running it three days a week and',
#   'will you get time off to do that ?'],
#  ['he took it', 'gawd you look awful'],
#  ['are you and dr woodly engaged ?', 'who have you been talking to ?'],
#  ['who have you been talking to ?',
#   'what difference does that make ? is dr woodly going to be my father now ?'],
#  ['whats happening to me ? why am i getting so much weaker ?',
#   'because your body can only take so much of what they are putting you through'],
#  ['laura', 'my names frank and furthermore you came back to see me tonight'],
#  ['my names frank and furthermore you came back to see me tonight',
#   'what if it wasnt you that i came back to see ?'],
#  ['did you see that about the guy who chopped up his wife into a million pieces ?',
#   'how could i miss it ? the tv wont quit with that stuff'],
#  ['how could i miss it ? the tv wont quit with that stuff',
#   'they are gonna cook him'],
#  ['rode right into them screaming like a banshee', 'my little web did that ?'],
#  ['those aint cops',
#   'and they sure aint from the neighborhood figure sabus in there ?'],
#  ['you', 'i got what i paid for'],
#  ['well all the same im going to advise starfleet and get instructions',
#   'im sure starfleet would approve sir'],
#  ['im sure starfleet would approve sir',
#   'i know but lets do it by the book stand by on this channel go'],
#  ['no ! he was crazy i didnt he looked i thought',
#   'okay okay take it easy dont freak out on me'],
#  ['okay okay take it easy dont freak out on me',
#   'do you have a mirror ? its the best way to see if someones breathing'],
#  ['poppa joe you want me to go now ?', 'yeah thanks rocco see ya'],
#  ['like i always do ?', 'thass right just play it'],
#  ['look mirtha shes walking', 'she did that before'],
#  ['she did that before', 'no these are her first steps watch her'],
#  ['as the man said its in my nature', 'whats that supposed to mean ?'],
#  ['you didnt tell us you were coming ?', 'then how did you know ?'],
#  ['i was wrong i admit it my bad okay ? now lets just go back to the ship',
#   'i dunno nice breeze wide open spaces you know im startin to enjoy myself out here'],
#  ['i dunno nice breeze wide open spaces you know im startin to enjoy myself out here',
#   'are you fucking high again ? just listen to'],
#  ['what is the dead poets society ?', 'any group pictures in the annual ?'],
#  ['any group pictures in the annual ?', 'nothing no mention of it'],
#  ['i need you to get me paula', 'you want her right now ?'],
#  ['you want her right now ?',
#   'yes now find her shes somewhere in the building'],
#  ['i was in the middle of', 'being utterly fucking useless what else is new'],
#  ['two minutes til krieger shows thisll have to be quicker than id like certainly quicker than youd like',
#   'ethan if you knew about jim ? why'],
#  ['it was an accident gifford too',
#   'the portraits lasher why are the witches always before a door ? tell me lasher now !'],
#  ['why ?', 'to bring you your birthright'],
#  ['to bring you your birthright',
#   'my birthright ? you mean like a trust fund ?'],
#  ['and you wanted him to make a list !', 'will you let him tell it !'],
#  ['will you let him tell it !', 'she never wants to hear she doesnt care !'],
#  ['what do you mean ?', 'he means they are thieving dogs'],
#  ['charley charley wow', 'i wish i didnt have to do this terry'],
#  ['give it a rest you were thinking the same thing just didnt have the guts to take the heat',
#   'we can horsetrade with khruschev on ships but it doesnt get us any closer to removing those missiles'],
#  ['we can horsetrade with khruschev on ships but it doesnt get us any closer to removing those missiles',
#   'have to hope its a signal that he ll back down on the real issue too'],
#  ['you want to try with me ?', 'things cant get much worse can they ?'],
#  ['things cant get much worse can they ?', 'i dont see how'],
#  ['i heard someone crying a woman',
#   'a woman crying ? no ones been crying here'],
#  ['i dont like this i dont like this at all', 'oh they are so cute'],
#  ['what are you going to do ?',
#   'hes expecting my call im going to the station and im going to call him'],
#  ['yes', 'one of my men is down i want to know what happened to him'],
#  ['i know i dont know anything',
#   'exactly dont you wonder where im really hiding simone ?'],
#  ['exactly dont you wonder where im really hiding simone ?',
#   'im sure youd tell me if you thought it was important'],
#  ['long trip pretty nice of you to come',
#   'well im close to her i wanted to meet the one that got away'],
#  ['well what ?', 'have you decided ?'],
#  ['have you decided ?', 'all i said was that it sounds like a good idea'],
#  ['then what the fuck ?', 'hey you dont know that shit for sure'],
#  ['hey you dont know that shit for sure',
#   'oh jesus you are such a fuckin retard !'],
#  ['nobody told me ! nobody told me ! you sold all of our stock ?',
#   'we dumped the whole load now quit showboating addison'],
#  ['i dont know what he was thinking',
#   'oh for gods sake what has this guy got a horse fetish ?'],
#  ['heather chandler is one bitch that deserves to die',
#   'killing her wont solve anything'],
#  ['let me see the plant press', 'what is it ?'],
#  ['they only kill them when they love them ?',
#   'what are you doing here i thought you were a nazi'],
#  ['churchill degaulle disraeli they all went through the pain of losing power',
#   'but they all got it back again didnt they ? we should have lunch sometime'],
#  ['yeah i know', 'are you ok ?'],
#  ['zero c mon dan i dont have all day', 'got a pencil ?'],
#  ['got a pencil ?', 'just give it to me i ll remember'],
#  ['didnt kill anything did i ?',
#   'a few rabbits but i think one of them was already dead'],
#  ['a few rabbits but i think one of them was already dead',
#   'that would explain the indigestion'],
#  ['how long was i out ?',
#   'three days i was worried about you how are you feeling ?'],
#  ['my people have a strict policy of non interference with other cultures in fact its our prime directive',
#   'your directive apparently doesnt include spying on other cultures'],
#  ['i never could count on you to be reasonable dont force me to make an adjustment around here',
#   'cobb you ve got nothing i need'],
#  ['cobb you ve got nothing i need',
#   'im not thinking about your future paden im worried about stella'],
#  ['sorry', 'hey its okay i like to pee so how are you doing ?'],
#  ['you wanted to be partners with me ?', 'sure itd be fun'],
#  ['why wasnt i involved from the beginning ? you and i started fight club together',
#   'fight club was the beginning now its out of the basements and theres a name for it project mayhem'],
#  ['i ll have to perform one of my operations !',
#   'no o o dont touch her ! no !'],
#  ['what report ?', 'you mean you dont know ?'],
#  ['we are locked in', 'are you insane ? he ll kill us both !'],
#  ['are you insane ? he ll kill us both !', 'maybe its better that way'],
#  ['you must have a bible in here dont cha ?', 'yeah we got a bible'],
#  ['yeah we got a bible', 'get it and bring it up here will ya please ?'],
#  ['ah my dear friend come in come in please sit down',
#   'im sorry i was at the theater and i didnt receive your note until i returned to my hotel'],
#  ['i cant its yours', 'take it damn it !'],
#  ['jes like in the catalogues aint they !', 'i seen em b fore you did'],
#  ['proper ? !', 'its against my programming to impersonate a deity'],
#  ['i guess i cut pretty loose in my day too',
#   'really frank ? when was that ?'],
#  ['really frank ? when was that ?', 'listen cant you wait till we get home ?'],
#  ['why ?', 'i wanted to use your car'],
#  ['her names libbets', 'libbets ? what kind of a name is libbets ?'],
#  ['libbets ? what kind of a name is libbets ?', 'the turkey in ?'],
#  ['im working for his daughter', 'that right ? she used to be some looker'],
#  ['yeah', 'how long you been up there fink ?'],
#  ['how long you been up there fink ?', 'a week eight nine days'],
#  ['its fine', 'they could put you in jail'],
#  ['kind of trouble im in the mood for',
#   'oh oh maybe i better get back in the truck'],
#  ['bastard you are going to need another nose !',
#   'but im not the type of guy to hold a grudge'],
#  ['had dinner at a place called the kings table buffet style it was pretty darn good',
#   'was it reasonable ?'],
#  ['now remember dont tell anybody we saw the terrance and phillip movie !',
#   'yeah lets swear we wont tell !'],
#  ['so pee ? here ?',
#   'yeah whip it out you want me to see it thats what this is all about right ?'],
#  ['yero by himself ?', 'maybe maybe with the crazy whites'],
#  ['tribuus tomorrow', 'you are coming back ?'],
#  ['what are you saying we cant stop whats out there ?',
#   'what the hell ? it shut us down'],
#  ['what the hell ? it shut us down', 'jerry ? please stop this'],
#  ['jesus holly we got enough time', 'okay but i dont want to miss him'],
#  ['okay but i dont want to miss him', 'follow that budjovice sign'],
#  ['yes laddie i have her', 'should i care ?'],
#  ['talk to me in the morning i feel like shit', 'but it cant wait'],
#  ['will you stop squawking !', 'look at me look at what they gave me to wear'],
#  ['no way man youd rob me blind !',
#   'but maybe its not so healthy being so close you know to a school'],
#  ['i cant do it jani',
#   'im asking you as a friend youd be saving the life of a friend'],
#  ['wait listen to me pappas if you dont let us by',
#   'we are all gonna die in this'],
#  ['my little niece she got this deep cough', 'you take her to a doctor ?'],
#  ['thats the building she lives on the seventh floor dont stop to look long the police are watching',
#   'where are they ?'],
#  ['where are they ?',
#   'i dont know you are not supposed to see them they are supposed to see you'],
#  ['you are as bad as harry', 'i ll go i ll go'],
#  ['really ?', 'you are going to blow everyone away'],
#  ['you cant tell anybody about this',
#   'i know i know but im saying if they knew we are going to be millionaires man millionaires !'],
#  ['we changed our minds', 'i got you a present'],
#  ['i got you a present', 'but i didnt get you one'],
#  ['when did you decide ?',
#   'its been a long time coming i finally made up my mind i guess it was thursday'],
#  ['its been a long time coming i finally made up my mind i guess it was thursday',
#   'hi im max cherry your bail bondsman'],
#  ['thats a lollipop that boy the kid is only great',
#   'and with ten percent of his future you are great too frank'],
#  ['and with ten percent of his future you are great too frank',
#   'went over to philly yesterday an seen the folks its nice you send them the fifty a month'],
#  ['lenny my dispatcher',
#   'i know you are out there ! answer the goddamn call !'],
#  ['i know you are out there ! answer the goddamn call !',
#   'what happens if you dont ?'],
#  ['nothing completely conclusive',
#   'i hope to we are working to develop this evidence'],
#  ['it takes all types', 'so whos he ?'],
#  ['so whos he ?', 'hes what she should run a mile from'],
#  ['i hope so hundred bucks apiece is a lot of dinero',
#   'what time are we supposed to get to the hotel ?'],
#  ['well there goes our record deal', 'nah we still got billy bob'],
#  ['you doing okay ?', 'got a job at old franks place his son runs it now'],
#  ['got a job at old franks place his son runs it now',
#   'oh man that kid takes himself real serious'],
#  ['ohh ! i wanted to sit next to leif',
#   'shut up you there you there and you there'],
#  ['you put me in an awkward position mr kessler', 'how is that ?'],
#  ['last present !',
#   'its a big one its a its a boardgame ! repeat ! battleship battleship the boardgame !'],
#  ['nowhere ? im here', 'for how long ?'],
#  ['for how long ?', 'oh i hope a long long time'],
#  ['they respond pretty quick i ll wait till you get down before i turn it on',
#   'good see ya soon'],
#  ['why ask me ?', 'because you are a pirate'],
#  ['because you are a pirate', 'and you want to turn pirate yourself ?'],
#  ['no',
#   'good it would be most unfortunate if i had to leave a permanent garrison here'],
#  ['yeah', 'it feels like you are in france'],
#  ['the world wants winners i guess not people stained with loserness',
#   'stained with loserness oh i like it can i use that itd be dynamite on interoffice memoranda'],
#  ['stained with loserness oh i like it can i use that itd be dynamite on interoffice memoranda',
#   'its all yours heather now if you ll excuse me im going to go throw up'],
#  ['morning', 'i wonder if you could help me'],
#  ['can india help us ?',
#   'india is a newly independent nation they are struggling india is in no position to help us'],
#  ['im not gonna quit cause of one creepy phone call george',
#   'come on erin a jobs supposed to pay your bills not put you in danger'],
#  ['so ?', 'so got the keys to heaven baby'],
#  ['yeah steve steve was all right for awhile',
#   'all right for awhile ? the guys good looking rich witty he was a god'],
#  ['what are you doing ?',
#   'well its a five minute walk or a thirty second drive'],
#  ['well its a five minute walk or a thirty second drive',
#   'you had better be careful'],
#  ['you invited me', 'only if you are a good man a friend are you a friend ?'],
#  ['this is humiliating we are being ejected from a prom !',
#   'hang in there i ll think of something'],
#  ['should i call you later ?', 'i ll just see you when you get back here'],
#  ['who is frank ?', 'a six foot tall bunny rabbit'],
#  ['well i suppose it would be all right for just a little while',
#   'would you like a sandwich ?'],
#  ['would you like a sandwich ?', 'no thanks ! i want to get right to sleep'],
#  ['third floor spare bedroom den what have you mr pearlstine used it as an office',
#   'hes talking about bernard pearlstine'],
#  ['yes james is very sweet why dont you get out your violin donna ?',
#   'sweet ? god hes gorgeous'],
#  ['lets ride', 'i am so sorry jesse'],
#  ['arent you giving an exam ?', 'i said dont worry about it'],
#  ['as surely as if it were my own ! harry give me back the enterprise ! with scottys help',
#   'no jim ! enterprise would never stand the pounding'],
#  ['no jim ! enterprise would never stand the pounding',
#   'then i ll find a ship i ll hire a ship'],
#  ['whos that ?', 'biff martin captain of the basketball team'],
#  ['biff martin captain of the basketball team', 'does he you know like me ?'],
#  ['you see ? life can be so simple', 'for twelve francs seventy five'],
#  ['george', 'hey baby say hello to felicia'],
#  ['hey baby say hello to felicia', 'i already said hello'],
#  ['why ?', 'i dont know you just are leaving a light for plato that was nice'],
#  ['boy holly holly',
#   'i just want a salad you really think im a loser dont you ?'],
#  ['i just want a salad you really think im a loser dont you ?',
#   'what do ? you are being ridiculous'],
#  ['thanks', 'most fun ive had all day'],
#  ['most fun ive had all day', 'you need to get out more'],
#  ['we arent completely stupid',
#   'stay in the light ! everybody ! stay in the fucking'],
#  ['stay in the light ! everybody ! stay in the fucking',
#   'we crossed our own tracks'],
#  ['what happened to you ?', 'i had a little run in with zowie'],
#  ['what ? my eyes are not lying !',
#   'yes they are josh since mankato they have been lying eyes'],
#  ['okay thanks', 'nice to know they cant seem to get along without ya'],
#  ['how violated i feel ?', 'you are not the only one'],
#  ['i warned you about playing that shit when im in the car',
#   'that was my cd dont you ever touch a chinese mans cd'],
#  ['waal mr moss i wouldnt',
#   'you wouldnt be here if it wasnt true its true right ?'],
#  ['no course not', 'hows it going ?'],
#  ['hows it going ?', 'great we got one of em'],
#  ['thanks', 'betsy come over here a moment'],
#  ['betsy come over here a moment', 'what is it ? im busy'],
#  ['i was wrong about you and u im u sorry',
#   'is that what you came here to say ?'],
#  ['is that what you came here to say ?',
#   'mainly and also that im proud very proud to be your son'],
#  ['claim ? oh claim thats what thomas asked me', 'thomas ? whos thomas ?'],
#  ['thomas ? whos thomas ?', 'thomas franklin an attorney'],
#  ['it was great for me how was it for you', 'a bit too quick'],
#  ['a bit too quick',
#   'well now we can do it slow are those some kind of stockings you are wearing ?'],
#  ['i think sometimes mrs little candor is the only kindness',
#   'all of your children are delinquent mrs little and one at least malcolm is a thief'],
#  ['what does time travel have to do with philosophy ?',
#   'guess who wrote it ?'],
#  ['i mean breakfast',
#   'yeah sure and i bet you had lobster last night along with two bottles of champagne'],
#  ['yeah sure and i bet you had lobster last night along with two bottles of champagne',
#   'just one bottle i believe in moderation'],
#  ['hows your shoulder ?', 'fine hows your back ?'],
#  ['you go boy',
#   'if its all the same to you id rather not dish right here in the middle of crankville'],
#  ['if its all the same to you id rather not dish right here in the middle of crankville',
#   'feeling the paranoia tonight are we ?'],
#  ['which question is that ?',
#   'the one you came up to ask are we on schedule ?'],
#  ['the one you came up to ask are we on schedule ?',
#   'take note mr mason this is why you hire a professional no whining no excuses'],
#  ['hi i brought some wine', 'thank you wont you come in ?'],
#  ['all right',
#   'uh huh mi raccomando italian american slang for im counting on you'],
#  ['what ?', 'talk about it right now i mean i got to um'],
#  ['communist viet cong', 'they left it in the jungle'],
#  ['and how is lord lavenham ?', 'and little lady beatrice ?'],
#  ['i dont suppose theres a drink left', 'you can have one at maxs'],
#  ['you can have one at maxs', 'i dont think im going'],
#  ['what ?', 'not u they u u he u'],
#  ['tell me about yourself', 'which part ? that or the day to day'],
#  ['which part ? that or the day to day',
#   'lets keep it the day to day stuff hows kevin ?'],
#  ['take it easy',
#   'theres no time to take it easy ! you dont realize the diabolical mind we are dealing with !'],
#  ['please sir', 'ive never ridden in an automobile'],
#  ['ive never ridden in an automobile',
#   'i assure you sir david is a very careful driver please wont you let us take you ?'],
#  ['dont tell me you are waiting for lightning to strike wide eyed romantics are an endangered species',
#   'that sounds kind of pessimistic'],
#  ['that sounds kind of pessimistic',
#   'no realistic theres no magic in the world girls just dont get swept off their feet anymore'],
#  ['you got me beat on both accounts', 'the hell i do'],
#  ['the hell i do', 'gabriel ? are you asleep ?'],
#  ['yeah a toon it was the guy who killed bambis mother',
#   'him ? oh he was vile heinous despicable a smear on the drafting board'],
#  ['but she is real it wasnt just a concussion',
#   'forget her you are mine i saw you first'],
#  ['the word of god', 'no henry try not to talk'],
#  ['no henry try not to talk', 'the name of god'],
#  ['its for wheat we ve always grown maize in the strip above the vegetables',
#   'and in the vegetable plot ?'],
#  ['yes sir', 'i am lieutenant dunbar'],
#  ['i am lieutenant dunbar', 'what is your number ?'],
#  ['hes not slowing', 'hes going to slow down'],
#  ['stay ? they lived together all their years ?', 'oh yes i think'],
#  ['so ? what do you think ? you think you are the one ?',
#   'honestly ? i dont know'],
#  ['she was a liar she was a liar !',
#   'answer my question ! werent you paid to get out of town ?'],
#  ['i dont', 'how did you meet him ?'],
#  ['how did you meet him ?',
#   'on a train he said he lived here and he offered to make a reservation for me'],
#  ['is it ever embarrassing having your bum kissed in public ?',
#   'if your ass isnt chapped you are not a good writer of note'],
#  ['so why are you even considering it ? are you ?', 'just like you would be'],
#  ['sounds great where do i sign up ?', 'i havent been out here for a while'],
#  ['i havent been out here for a while', 'you go by your old house ?'],
#  ['looks like a design some writing maybe maybe it was sent to meet the spacecraft with a message',
#   'look closely that isnt writing those are grooves'],
#  ['look closely that isnt writing those are grooves',
#   'no they dont represent a message they arent decorative at all they have another purpose entirely'],
#  ['woody ? ! what are you doing ?', 'hold still buzz !'],
#  ['yeah mack ?', 'captain this is some spooky shit we got here'],
# ...
#   'code ive heard a lot about this'],
#  ['i am', 'thats a big help where are you from ?'],
#  ['yes', 'and you didnt send her to a doctor'],
#  ['and you didnt send her to a doctor', 'i didnt guess until it was too late'],
#  ['just come to the mudd club on friday',
#   'i dont go there too many party girls'],
#  ['i dont go there too many party girls', 'party girls ? can i call you ?'],
#  ['any way fate stepped in and took football out of the equation',
#   'and everyone lived happily ever after'],
#  ['ive got nothing to say to you', 'you know what happened'],
#  ['what ?', 'hello can you hear me now ?'],
#  ['hello can you hear me now ?', 'whats happening ? !'],
#  ['no no thats ray here ray uh ray little weasel',
#   'leos gotta get to burial brother hes gotta make the journey'],
#  ['oh', 'you may not remember things'],
#  ['well if its already too late',
#   'its never too late give those cigarettes back now and buy some gum instead here chewlies gum try this'],
#  ['your wife ?',
#   'shes gone and the present is trivia which i can scribble down as notes'],
#  ['no', 'why didnt you tell me ? why didnt you hold him ?'],
#  ['you cant come to southern italy and not see the blue grotto',
#   'i just need to run up and get my bathing suit'],
#  ['i just need to run up and get my bathing suit',
#   'okay i ll meet you at the dock in ten minutes'],
#  ['oh how beautiful !',
#   'it reminded me of you so i bought it it cost me more than all the others'],
#  ['it reminded me of you so i bought it it cost me more than all the others',
#   'i shall wear it in my hair !'],
#  ['i understand that you had a rather unfortunate encounter with the police tonight',
#   'yes sir i suppose you might call it that sir'],
#  ['yes sir i suppose you might call it that sir',
#   'hahaha and how are you feeling now ?'],
#  ['seventeen minutes',
#   'armor up sick sticks and concussion guns this is gonna be close'],
#  ['everybody has one like that i thought it was great when you started to laugh at the end',
#   'yeah well im sorry im tying up jane i didnt realize you two would be going this late sorry'],
#  ['yeah well im sorry im tying up jane i didnt realize you two would be going this late sorry',
#   'no dont worry about it'],
#  ['that was my choice nothing to do with you i took a chance and it didnt work out',
#   'bluebell came in ?'],
#  ['im into garbage its my thing',
#   'boy this is really a nice screening room its really a nice room'],
#  ['they got a sign on him says he was a killer', 'a sign on him ?'],
#  ['no i see her around the pool i know her i know her like that not like that',
#   'nah not now i wanna wait i dont feel right'],
#  ['nah not now i wanna wait i dont feel right',
#   'im tellin you she ll be there i know she ll be there'],
#  ['funny so am i',
#   'congratulations unfortunately my train is about to leave and i really must insist you disembark'],
#  ['looks like you did more than jackoff while i was gone',
#   'maybe are animating you wasnt such a bright idea you look like shit'],
#  ['why terry who said it was ?',
#   'well nobody i guess but that father barry i didnt like the way he kept lookin at me'],
#  ['well nobody i guess but that father barry i didnt like the way he kept lookin at me',
#   'he was looking at everybody the same way asking the same question'],
#  ['did we create his mind too ? not only can this man speak he can write he can reason',
#   'he can reason ? with the tribunals permission let me expose this hoax by direct examination'],
#  ['he can reason ? with the tribunals permission let me expose this hoax by direct examination',
#   'proceed but dont turn this hearing into a farce'],
#  ['people are talking they say the yakuza has a contract out on you',
#   'i hear that shit once a week dont worry jo jo bao loves me'],
#  ['yeah how did you know ?',
#   'i just know thats all i remember you from central'],
#  ['no no no no no', 'the kind of man that could have killed edie finneran'],
#  ['let him go', 'that son of a bitch dont get me wrong hes a fine writer'],
#  ['that son of a bitch dont get me wrong hes a fine writer',
#   'i ll jus walk on down to the pacific and from there i ll improvise'],
#  ['i ll keep that in mind', 'we are in business'],
#  ['we are in business', 'good work flynne you are a first rate rat'],
#  ['go ahead', 'no nothing ive got a problem i guess'],
#  ['no nothing ive got a problem i guess',
#   'were you bothering by those waitresses making a fuss ?'],
#  ['by my head here come the capulets', 'by my heel i care not'],
#  ['by my heel i care not',
#   'follow me close gentlemen gooday a word with one of you ?'],
#  ['now that is very interesting take a chair joseph',
#   'can anyone hear what we say ?'],
#  ['you werent at my game',
#   'yeah sorry about that i had this meeting with this guy'],
#  ['yeah sorry about that i had this meeting with this guy',
#   'yeah i hit a three at the buzzer'],
#  ['really ?', 'i could pencil you in if you like ?'],
#  ['i could pencil you in if you like ?', 'i ll take a rain check for now'],
#  ['any idea what he did ?',
#   'oh the scuttlebutt for awhile was he was investigating kennedy'],
#  ['hier sind fruher fursten ans unt eingeganger hier hat sogar ein metternich verkehrt',
#   'give her some cigarettes'],
#  ['watch your mouth',
#   'monica i think her point is maybe its time to start thinking about other things besides basketball'],
#  ['but i am history',
#   'of course your highness nevertheless cure the marquis de sade succeed where countless physicians and priests have failed'],
#  ['huh ?', 'you met the gift'],
#  ['draw', 'whats your record at ?'],
#  ['not yet', 'i ll be forced to tickle you'],
#  ['rosa',
#   'well what if this guys just playing with you ? what if hes lying about who he is ?'],
#  ['i ll tell you the problem you behind the wheel theres your fucking problem',
#   'thats pretty simplistic dont you think ?'],
#  ['could we sit down someplace ?',
#   'im sorry ive had you on your feet for hours'],
#  ['no i dont think so',
#   'well think because theres footprints here that arent mine'],
#  ['well think because theres footprints here that arent mine',
#   'well they are not mine'],
#  ['so ?', 'you want to take a look at my car ? i think the radiator hose is'],
#  ['i have a plan if it succeeds then any battle will be decidedly brief and one sided',
#   'whats your plan ?'],
#  ['not at all', 'sure you want to keep those in the house ?'],
#  ['sure you want to keep those in the house ?',
#   'im so sorry about that it was rude i think i just got nervous for some reason'],
#  ['hey they are ralph laurens and whos this interesting looking fellow ?',
#   'this is adam adam meet cliff'],
#  ['this is adam adam meet cliff', 'how do you do ?'],
#  ['im hungry',
#   'take your choice ive got enough so we wont have to go out of the house till tuesday'],
#  ['take your choice ive got enough so we wont have to go out of the house till tuesday',
#   'what did all this stuff cost you ?'],
#  ['oh yes ? and whats so intelligent about writing a requiem ?',
#   'money ! money !'],
#  ['money ! money !', 'you are mad ! shes mad wolfi'],
#  ['dont worry i plan to have something within twenty four hours john',
#   'how the hell are you going to do that ?'],
#  ['hi there little brother', 'say hi to paul'],
#  ['what are you askin me for put em in the first helicopter comes in tomorrow',
#   'nobody comes in here'],
#  ['i wont talk about the other two',
#   'but they both worked at the white house ?'],
#  ['but they both worked at the white house ?',
#   'i will not talk about the other two'],
#  ['i can see and you also brought a nice girl to come eat by us',
#   'so do you have a name ?'],
#  ['majesty',
#   'delightful court composer would you permit me to play it as he comes in ?'],
#  ['delightful court composer would you permit me to play it as he comes in ?',
#   'you do me too much honour sire'],
#  ['neither had i odd desire for a woman i guess', 'odd desire for anyone'],
#  ['round the world in eighty days hello kris',
#   'you are amazing what are you doing mr parker ?'],
#  ['have you ever talked to carl tried to see his side ?',
#   'his side ? ive seen it all right a nice bright yellow !'],
#  ['hmm nice',
#   'its really pretty outside how about taking me for a walk after you ve finished your breakfast ?'],
#  ['its really pretty outside how about taking me for a walk after you ve finished your breakfast ?',
#   'oh i suppose i oughta try to do some writing first'],
#  ['im just resting my feet',
#   'remember the first round how i had him against the ropes and'],
#  ['remember the first round how i had him against the ropes and',
#   'i ll never forget it i thought it was all over'],
#  ['the movers', 'yes i know this path louis ? where does it go ?'],
#  ['yes i know this path louis ? where does it go ?',
#   'i dont have the slightest idea when i saw the house this field was under four feet of snow'],
#  ['i rat cecile out to mommy mommy goes ballistic and ends their relationship boo hoo',
#   'but who will they turn to for help ?'],
#  ['hes developing a hemisphere imbalance', 'talk so i can understand'],
#  ['some hollywood movie star her plane got in late',
#   'discouraging isnt it ? women with furs like that where it never gets cold'],
#  ['im not rambling', 'you are talking like a madman'],
#  ['have you been in boulder long mrs torrance ?',
#   'only about three months eh we are from vermont my husband was teaching school there'],
#  ['what do you want me to start with the golden gate bridge ?',
#   'now i look up i look down i look up i look down nothing to it'],
#  ['now i look up i look down i look up i look down nothing to it',
#   'stop kidding wait a minute'],
#  ['well try huh',
#   'i dont know if i can its just that war is war things happen'],
#  ['is there anything you do know ?', 'i know you are a pussy i know that'],
#  ['i know you are a pussy i know that', 'all right lets get out of here'],
#  ['yes why do you think you woke and they didnt ?',
#   'i dont know maybe im a light sleeper'],
#  ['i dont know maybe im a light sleeper',
#   'loks like you had a break in up here as well'],
#  ['just relax', 'i dont need to relax the woman put her on'],
#  ['i dont need to relax the woman put her on', 'you ll see her'],
#  ['only at the very end', 'how do you feel after a shooting'],
#  ['how do you feel after a shooting', 'like it had to be done'],
#  ['are we going to argue ?',
#   'id love to argue with you sometimes but you are never here !'],
#  ['id love to argue with you sometimes but you are never here !',
#   'perhaps i was never meant to live with a woman'],
#  ['wait its nancy',
#   'im sorry but you could ve been the one doing all of this'],
#  ['chekov who is this man ?',
#   'a criminal captain a product of the late th century genetic engineering'],
#  ['a criminal captain a product of the late th century genetic engineering',
#   'what do you want with us ? i demand'],
#  ['whoa whoa come on hes making too much noise',
#   'you hear that bitch ? be quiet !'],
#  ['what are you doing in the ship ? beth ?',
#   'getting food we were out of food whats wrong ? you sound mad'],
#  ['getting food we were out of food whats wrong ? you sound mad',
#   'yeah well i get that way when im facing death and someone deserts me'],
#  ['im not sure i know you well enough i dont think im comfortable',
#   'yo im not comfortable either'],
#  ['i am uncertain', 'spock im really tired'],
#  ['that so', 'all i wanted him to do was let mickey out for christmas'],
#  ['all i wanted him to do was let mickey out for christmas',
#   'who is mickey ?'],
#  ['i know about that shot a terrible tragedy how much do you have for carrying on your investigation ?',
#   'if you must know virtually nothing'],
#  ['we are not yet open for business im afraid',
#   'shame i was recommended by a friend'],
#  ['nobody u lives u on this lake its really u his u lake now',
#   'c mon hector i know you are crazy but you cant'],
#  ['c mon hector i know you are crazy but you cant',
#   'i need to see his habitat'],
#  ['no', 'how do you know ?'],
#  ['rekallrekallrekall you thinkin of goin there ?', 'i dont know maybe'],
#  ['my god what the hell are you ?', 'hurry the woman needs help !'],
#  ['why dont i ?', 'no no no no no no wait'],
#  ['i cant write anything by tomorrow',
#   'who said write ? jesus jack cant read you gotta tell it to him tell him something for chrissake'],
#  ['im sorry im late', 'whats the hurry ?'],
#  ['we cannot break free captain we do not have a fraction of the power necessary',
#   'delay that order scotty ! disengage all main drive systems !'],
#  ['i told you', 'you tell me again'],
#  ['yeah lloyd what are your plans for the future ?',
#   'spend as much time as possible with diane before she leaves'],
#  ['is he out ?', 'like the rock of gibraltar'],
#  ['fuckin a',
#   'sorry about that pete but tailgating is one thing i cant tolerate'],
#  ['mirrors', 'luckiest guy in the northern fucking hemisphere is all ims'],
#  ['luckiest guy in the northern fucking hemisphere is all ims',
#   'what ? because im a little understand'],
#  ['how ?',
#   'well it still sucks but you start to see that there are advantages to being single'],
#  ['where could he have gone ?',
#   'maybe he got some definite lead maybe he went right on'],
#  ['what is it this time ?',
#   'a man came by the house a psychiatrist by the name of loomis'],
#  ['remember phillippe nobility is born in the heart',
#   'hold your goblet with two fingers'],
#  ['what did i get ?', 'yeah what vibe ?'],
#  ['yeah what vibe ?',
#   'i detected no vibe other than that ruiz thinks you are a fucking idiot'],
#  ['if hes nuts why doesnt the state just put him away ?',
#   'because it happened to be a colored policeman'],
#  ['because it happened to be a colored policeman',
#   'the colored vote happens to be very important to the mayor of this town'],
#  ['who wrote this book ?',
#   'scientists who have been persecuted for their beliefs'],
#  ['scientists who have been persecuted for their beliefs',
#   'that means they are unemployed'],
#  ['here we go again',
#   'you know women normally change five times more than men'],
#  ['you know women normally change five times more than men',
#   'you get that off the screen ?'],
#  ['i still am', 'is that right ?'],
#  ['this is not going well', 'hurry ! queen cherlindrea will know what to do'],
#  ['we are going to lose', 'you cant know that for sure'],
#  ['been better i read about whats been happening with you i should have called',
#   'what kind of trouble are you in ?'],
#  ['thank you sir',
#   'let us remember this night and tell the world that even in hell there are good people'],
#  ['no ! dont kill him !', 'it john not him it'],
#  ['it john not him it', 'alright it ! we need it !'],
#  ['yeah well',
#   'its just my stupid way of getting attention ! god i practically love you josh !'],
#  ['ambulance', 'we are just gonna take some blood here'],
#  ['dont you think we should at least pull over and offer to clean it off ?',
#   'what ? ! are you mentally deranged jam ?'],
#  ['we appreciate your help with this', 'so whats the deal ?'],
#  ['no', 'what about guinan ? what has she told you about me ?'],
#  ['what about guinan ? what has she told you about me ?',
#   'guinan ? i dont know what you are talking about'],
#  ['we are not saying anything about that night to the police we should all forget that night',
#   'what happened to me ?'],
#  ['atlantic city ?',
#   'i know its a drag but you cant find a hotel room in town not on new years eve'],
#  ['i need to know', 'you need to know what ? do i still love you ?'],
#  ['hi baby ive missed you',
#   'i know lenny if tran finds you talking to me he ll hurt you'],
#  ['i can explain', 'sure ! you are never at a loss for words'],
#  ['thats the one whatever happened to him ?',
#   'he pulled it on rorschach and rorschach dropped him down an elevator shaft'],
#  ['pardon ?', 'oh no mrs robinson oh no'],
#  ['what about our grenades ?',
#   'those are tigers they have six inch armor they dont even notice grenades'],
#  ['the sounds but not the language we would be responding in gibberish',
#   'is there any other planet where this species exists ?'],
#  ['is there any other planet where this species exists ?',
#   'the humpback was indigenous to earth earth of the past'],
#  ['i saw the show', 'well maybe it works on fingers too'],
#  ...]

# %%
new_pairs = []
for pair in final_pairs:
    if len(pair[1].split(" ")) > 3:
        pair[1] = pair[1].replace(".","")
        new_pairs.append([pair[0],pair[1]])
        
new_pairs
# Out:
# [['negro what the hell you doing to my woman ?', 'i dont know !'],
#  ['shut up miss henried ! i tol ya b fore !',
#   'this is a travesty ! captain rhodes is'],
#  ['objection',
#   'sustained yes the witness will confine his testimony to review of the hospital records'],
#  ['whats wrong skipper ?',
#   'what i was afraid would happen the stuff we passed through that looked like seaweed'],
#  ['what ?', 'you just burned the desk'],
#  ['she shore dont look prosperous want to go somewheres else ?',
#   'on a gallon a gas ? lets set up the tent maybe i can fix us up some stew'],
#  ['i i think i understand i think i get it',
#   'no what you are feeling is premature enlightenment'],
#  ['look maybe id better talk to dick is he around ?', 'dick ? dick who ?'],
#  ['a married lady', 'with the paper to prove it'],
#  ['they ll be back he had to go in for a urinalysis',
#   'would you care for a drink while you are waiting ? i can put it on the underhill bill'],
#  ['would you care for a drink while you are waiting ? i can put it on the underhill bill',
#   'great i ll have a bloody mary and a steak sandwich'],
#  ['i didnt', 'i put everything in my room my teddy bear is joining us'],
#  ['hi oh hi hi', 'well bye she laughs and backs up slowly toward the door'],
#  ['well bye she laughs and backs up slowly toward the door',
#   'you you play very well'],
#  ['the night is a tunnel a hole into tomorrow if we are to have a tomorrow',
#   'remember walk without rhythm and we wont attract a worm it ll go to the thumper'],
#  ['when the stiffs an irish the cops take it kinda personal',
#   'cant we get a couple whores over ?'],
#  ['cant we get a couple whores over ?', 'you aint even a man yet'],
#  ['what is this ? dont be stupid man',
#   'first you question my integrity then you call me stupid that hurts son'],
#  ['hello may i speak to mitch brenner please ? yes i ll wait',
#   'insist on making it difficult for life to survive on this planet if it werent for birds'],
#  ['at first', 'you got anybody wick ?'],
#  ['do you ?',
#   'i know that this was probably a great white shark car cadon caradan'],
#  ['if i ever loved narcissus it wasnt like you want',
#   'but i get what i want always dont i ?'],
#  ['do you mind this is like the most important moment of my whole life',
#   'forget it jen ive waited a year for this'],
#  ['and look what you ve done to mr bigglesworth !',
#   'we could not anticipate feline complications due to the reanimation process emdash'],
#  ['i gotta figure some way out of this thing !',
#   'the elevators are still runnin'],
#  ['my wife ?', 'yeah uh they brung her to the county jail uh'],
#  ['yes the big celebration of my mandatory retirement birthday you are an honored guest eddie',
#   'im going to stick it out here we still have a shot'],
#  ['the uh cynthia branson estate was worth how much ? because her family',
#   'what family ? we never heard from them i sold her house for them made them money'],
#  ['listen i want to talk to you about the prom',
#   'you know the deal i cant go if kat doesnt go'],
#  ['it aint even three years we been married',
#   'three years ago i said them very words no and good'],
#  ['twenty percent', 'fine i want half plus the release of the family'],
#  ['non e questo il luogo per le vostre conversazioni private !',
#   'a ragione a ragione'],
#  ['a ragione a ragione', 'hmm c e questa'],
#  ['you guys are crazy you know that ? i mean you guys are really nuts',
#   'hes getting married and we are nuts !'],
#  ['hes getting married and we are nuts !',
#   'its all right hey its all right we ll be right here right with you'],
#  ['i presume youd prefer handling the delivery',
#   'all i said was i dont want to perform abortions i have no argument with you performing them'],
#  ['that looks like fifty thousand dollars from here', 'this is your money ?'],
#  ['this is your money ?', 'if i were to tell you no it isnt'],
#  ['of course', 'it was not inspired by circumstance'],
#  ['it was not inspired by circumstance', 'no it most certainly was not'],
#  ['jack you are wrong', 'good afternoon mr brumby carter exits'],
#  ['next stop', 'pizza planet ! yeah ! ! !'],
#  ['hi daddy', 'well what happened to you ?'],
#  ['well what happened to you ?', 'i won a flower'],
#  ['please paul why do we have to go to the roof ?',
#   'its alright this is the only place i can find some peace'],
#  ['no why ?', 'you sure hes not italian ?'],
#  ['you sure hes not italian ?', 'hes black ok ?'],
#  ['gatling ! they ve got a gatling !',
#   'dammit this stopped being fun about two years ago !'],
#  ['do i ?', 'it happens take it easy'],
#  ['whats up with you ?', 'me ? nothing tell me more about the job'],
#  ['last night you were talking to someone in the corridor',
#   'you must have been dreaming'],
#  ['dont hold back on us max we need all the help we can get',
#   'fucked up chromosomes man think about it their parents all dropped acid in the sixties'],
#  ['fucked up chromosomes man think about it their parents all dropped acid in the sixties',
#   'it beats dr simms theory she thinks its nothing but sex drugs and rock roll'],
#  ['as you will', 'you must look at my face and not at the floor'],
#  ['it has been taken freylag and all his people slaughtered',
#   'it is only a few weeks and already half our strong places have fallen'],
#  ['and how much are these ?',
#   'seventy eight dollars the girl who rolled these was probably wearing panties'],
#  ['im very sorry i',
#   'you are very sorry you passive aggressive son of a bitch can we replace him ?'],
#  ['its something ive always wanted to do',
#   'you actually could make breaking and entering into a new career so what are you doing here ?'],
#  ['do you like this hotel ?', 'yes i do i love it dont you ?'],
#  ['sorry', 'so hows college ?'],
#  ['well i think its getting late good night ninotchka',
#   'thank you for a wonderful dinner'],
#  ['sir august merryweather why are we seeing him first ?',
#   'as per mothers instructions'],
#  ['the goddamn smell is always the same',
#   'are you going to be able to sleep ?'],
#  ['are you going to be able to sleep ?',
#   'yeah i think so mike ! keep it down for chrissake !'],
#  ['dont explain', 'how long you going away for ?'],
#  ['shoot him nicky not that we really mean it but where does he live ?',
#   'keep going west last building before the river'],
#  ['keep going west last building before the river', 'how do you eknow'],
#  ['oh uh my stepmom took me to the doctor yesterday and they said i was twelve weeks',
#   'oh thats marvelous so you are almost into your second trimester then ?'],
#  ['oh thats marvelous so you are almost into your second trimester then ?',
#   'yeah apparently im having it on may'],
#  ['you think so ?',
#   'yeah ive always hated that kid he used to eat glue in like seventh grade'],
#  ['no thanks', 'you are my mothers hairdresser ?'],
#  ['you are my mothers hairdresser ?', 'i do her hair yeah'],
#  ['well',
#   'i mean you dont exactly have the build for a football i mean no offense'],
#  ['i mean you dont exactly have the build for a football i mean no offense',
#   'no you are right'],
#  ['its already planned mike its going to cost at the free clinic',
#   'doesnt sound free to me so you want me to pay for it ?'],
#  ['doesnt sound free to me so you want me to pay for it ?',
#   'half okay ? seventy five dollars and a ride to the clinic'],
#  ['annette ?',
#   'devastated beyond repair i doubt she ll ever trust a man again'],
#  ['dig the square wardrobe !', 'yeah so wheres the high school ?'],
#  ['yeah so wheres the high school ?',
#   'university and th want to carry my books ?'],
#  ['whats the matter boys ? is my slip showing ?',
#   'i ll say it is you spilled a little borscht on it'],
#  ['miss kubelik you shouldnt be out of bed',
#   'i didnt know i had no idea this was your apartment'],
#  ['i didnt know i had no idea this was your apartment', 'let me help you'],
#  ['gus if theres anything i hate its greed',
#   'greed ! let me tell you something'],
#  ['you ve been following me ?',
#   'her its an obvious move im building a case against her remember ?'],
#  ['superman ! the', 'really lois we ve got to stop meeting this'],
#  ['really lois we ve got to stop meeting this',
#   'the bomb ! its in there ! any second now its'],
#  ['he does it right in front of him',
#   'its getting better and better keep going'],
#  ['i think someone broke into my house', 'no shit ? !'],
#  ['how did you get onto doom ?',
#   'marvin told me doom was after his land ne was afraid thats why he brought me his will'],
#  ['marvin told me doom was after his land ne was afraid thats why he brought me his will',
#   'so where is it ?'],
#  ['im searching for patterns in the noise thats all order in the chaos im practicing listening',
#   'the point is this isnt just scientific inquiry anymore its turned into some kind of personal obsession'],
#  ['you are hot tonight honey but be quiet ! shhhh ! the kids !',
#   'yeah ! oohhhh ! get it !'],
#  ['yeah ! oohhhh ! get it !', 'ooh honey im ready ! now ! now !'],
#  ['im just giving you the truth there was a time when william parrish liked the truth',
#   'i think its time you went home drew'],
#  ['i know but since we are talking i thought id mention it',
#   'we are not talking you are talking and doing too damn much of it if you ask me'],
#  ['two hundred and fifty dollars you owe met', 'you found the leopard !'],
#  ['field trip ?', 'lunch hour my next class isnt till nine thirty'],
#  ['it surprises me it really does',
#   'any person who spends a significant amount of time with me finds me disagreeable just ask your husband'],
#  ['its muscles are locked', 'oh jesus ! !'],
#  ['im really sorry',
#   'bullshit ! you hate us if you had half a chance youd feed us to them !'],
#  ['i hear they need a new lieutenant want the job ?',
#   'i ll take it until i get killed or you find someone better'],
#  ['good girl', 'and what do you do wh'],
#  ['do you realize what i can create with a single strand of supermans hair !',
#   'a toupee that flies ?'],
#  ['we are hungry do you have anything to eat ?', 'anything to eat ?'],
#  ['clear', 'clear meadows that shits dead'],
#  ['a giant hydraulically operated microscope that explodes ? or maybe just someone who hates scientists',
#   'then why kidnap them ? why not just kill them ?'],
#  ['then why kidnap them ? why not just kill them ?',
#   'ay theres the rub take a look at this file on professor morton quite a brilliant fellow metallurgy'],
#  ['you okay ?',
#   'yeah im just gettin old i cant smoke or laugh now it seems without coughing'],
#  ['no no dont cry at the beginning of the date', 'oh knock it off !'],
#  ['say whos putting up this dough ?',
#   'feller runs the chronicle heres the speech you makeand its all written out for you'],
#  ['all right now theres milk and cookies in the refrigerator go to bed right after falcon crest',
#   'ed we are so glad you could come over at the last minute and judge our little beauty pageant'],
#  ['why not ?', 'i just cant okay ?'],
#  ['not exactly', 'they were vampires werent they ?'],
#  ['would you like us to notify anyone for you ?',
#   'no the old man died and louise left'],
#  ['oh harry im so proud of you making a real friend',
#   'is it okay if he spends the night ?'],
#  ['is it okay if he spends the night ?', 'lloyd did you ask your parents ?'],
#  ['thanks but i ll take the bus i do it all the time',
#   'dandridge is a condescending prick ride with me it would be because i want you to'],
#  ['i dont know',
#   'im sure he wont be angry once he realizes how concerned you are about him'],
#  ['its over !', 'what is your wifes picture doing by the side of your'],
#  ['what is your wifes picture doing by the side of your',
#   'what is that to you ?'],
#  ['yes why not', 'ada says you are doing well with the piano ?'],
#  ['oh my god ! i almost forgot i got you a meeting with the admissions guy from dartmouth !',
#   'what ! but i wasnt even going to go to college'],
#  ['we cant', 'any word from him ?'],
#  ['i didnt know you were out', 'did it seem short to you ?'],
#  ['did it seem short to you ?',
#   'thats all over as far as im concerned emmett im satisfied'],
#  ['huh ?', 'i just saw a man walk out of your room'],
#  ['okay i know you ve been scared now you want to scare someone',
#   'does that scare you ?'],
#  ['whats your name ?', 'me ? willie long'],
#  ['me ? willie long', 'what are you in for willie ?'],
#  ['holy smoke ! a half a heelot !',
#   'there you are boss just like you ordered symbols of the little people'],
#  ['camels same as me guess both my mama and my daddy died of smoke or alcohol related illness',
#   'gee sailor im sorry honey i never would have guessed it'],
#  ['sailor aint a boy no more mama', 'dont mean him its pace concerns me'],
#  ['dont mean him its pace concerns me', 'really mama i gotta go'],
#  ['hejira', 'and so now you are off to glades'],
#  ['could buy a lot of steaks dollars',
#   'i cant be positive that it was used for the break in but people sure are worried'],
#  ['mr peterson are you sure mama wrote all this ?',
#   'well it was notarized and witnessed by a mrs lucy delaney maybe you can ask her'],
#  ['well it was notarized and witnessed by a mrs lucy delaney maybe you can ask her',
#   'who the hell is lucy delaney ?'],
#  ['we didnt sign on for this shit fuck ! this shit is intense i need to call my agent',
#   'just shut up and do what they say they are gonna kill us if we dont ian'],
#  ['of course', 'so whats her name ?'],
#  ['so whats her name ?', 'you know i got a lot more than one'],
#  ['is it set ?', 'primed to go off right over his head officer'],
#  ['hows it going ?',
#   'its going fine the quiet riot and me are swapping trade secrets'],
#  ['oh harry you are so funny now i have something thats kind of delicate',
#   'oh you want to talk about your delicates ?'],
#  ['oh you want to talk about your delicates ?',
#   'are you trying to be funny ? or are you actually are re special'],
#  ['no of course he lives there would i point it out to you if he didnt ?',
#   'that w as p bastard'],
#  ['that w as p bastard', 'you are intolerable today'],
#  ['just like that ?',
#   'just like that load up the lincoln point it west stop when we hit the fucking ocean'],
#  ['water mains usually go in the winter its august st',
#   'tell you what reminds me of life in the delta'],
#  ['so what did you want ? i think we understand each other no ?',
#   'you dont understand me'],
#  ['you dont understand me', 'you dont understand you either'],
#  ['hello ?',
#   'where are you ? you are driving me crazy waiting like this i want you in me now !'],
#  ['how did you get into the business ?',
#   'the same way everyone does the government the agency'],
#  ['i dive in search of god if i go deep enough im going to find him',
#   'a little you think its the same for jacques ?'],
#  ['good morning', 'thats all the gusta you can musta ? i said good morning !'],
#  ['do you have any more of these deli cious cookies ?',
#   'anything else mr black ? how about some water ?'],
#  ['you broke a dozen training rules back there before i lost count',
#   'ive had it just because they pay me like a baby sitter doesnt mean im gonna be one'],
#  ['ive had it just because they pay me like a baby sitter doesnt mean im gonna be one',
#   'shes a trainee just like the others why are you coming down so hard ?'],
#  ['when i gave you my gun and you almost shot me',
#   'maybe you should see a psychiatrist'],
#  ['i cant say that !', 'no you can tell him to get on the fucking phone !'],
#  ['i ll fuckin give it to him ! we ll go down there',
#   'you dont understand he wants all the money that is in your bank'],
#  ['you dont understand he wants all the money that is in your bank',
#   'ive got eight hundred pounds oh jesus'],
#  ['ask not for whom the telephone rings', 'no please ! i beg you'],
#  ['no please ! i beg you', 'walk over to the window'],
#  ['or ?', 'they revoke our flight status'],
#  ['they revoke our flight status', 'oh i see teamwork'],
#  ['the dishes ?', 'i mean after that ?'],
#  ['ah did you hear that ? spooky loved you',
#   'yeah pretty gross hurry we ve got work to do'],
#  ['i might', 'nice car how much did you pay for it ?'],
#  ['no it wont do', 'what wont do ?'],
#  ['what wont do ?', 'you are much too human'],
#  ['he ll try to finish his experiment',
#   'and blow up the universe just to prove hes right ? bit egotistical isnt it ?'],
#  ['no', 'did your husband strike or physically abuse his child in any way ?'],
#  ['nothing', 'then whats going on ?'],
#  ['then whats going on ?', 'i went to the doctor today'],
#  ['calm down you are not', 'calm down look at this look at him !'],
#  ['what did he do this time ?',
#   'y know all those pictures he has hanging on the wall of fame ?'],
#  ['you are too young to be studying criminal behavior its making you obsessive',
#   'she is kicking you out'],
#  ['if they dont tell me what i need to know', 'doesnt it get tiring ?'],
#  ['you lied',
#   'i equivocated but you are not their big worry at present its dr darling hes disappeared'],
#  ['shes tired', 'its bad news when you cant even bribe kids'],
#  ['its bad news when you cant even bribe kids',
#   'i want you so bad she ll be asleep soon maybe we could do it quietly under the sheets'],
#  ['just kidding',
#   'gabe ? wait til i get over there tie the rope so i can come across'],
#  ['ethan hunt', 'well ethan hunt what is it you want to talk to me about ?'],
#  ['shouldnt they be there by now ? whats taking them so long ? !',
#   'hey these guys are professionals they are the best c mon they are not lying down on the job'],
#  ['no dollar', 'hey give rocky a dime'],
#  ['its been a while', 'wheres the dog ?'],
#  ['wheres the dog ?', 'appreciate the loan im good for it'],
#  ['huh let me think', 'you sure you didnt say anything to maya ?'],
#  ['crabs would get most of the newborns before they made it to the sea huh ?',
#   'yeah but not now these will all make it guaranteed'],
#  ['yeah but not now these will all make it guaranteed',
#   'whatever i say you ll take him away wont you ?'],
#  ['listen harry i didnt believe that', 'its good to see you holly'],
#  ['what are you talking about ?', 'think what you have time to think lester'],
#  ['yes ?',
#   'mrs stanwyk i hate to disturb you tom underhill here im a new member'],
#  ['it may be that i could confer with my colleagues on this and get back to you',
#   'would you doctor ? that would be so kind'],
#  ['whats this ?', 'why dont you open it and find out ?'],
#  ['why dont you open it and find out ?',
#   'jesus god auggie theres money in here'],
#  ['tis the season convict', 'cant be attracting attention right ?'],
#  ['cant be attracting attention right ?',
#   'what we walking in there and delivering toys ?'],
#  ['and im arranging deportation papers',
#   'yes yes thats eminently fair of you'],
#  ['yes yes thats eminently fair of you',
#   'and im bringing you in and locking you up until you tell me'],
#  ['scalping to a funeral you are a pretty sleazy guy',
#   'thanks you interested its festival seating so'],
#  ['you have no sick time frank no time of any kind everyone knows that',
#   'take me back put me to bed i surrender we ve done enough damage tonight'],
#  ['sure !', 'of course honey come in bed with us come on'],
#  ['i added air conditioning put in the pool made all those pillows by hand',
#   'yeah ? i should learn to do stuff like that they make the place feel real homey'],
#  ['that is so sad',
#   'i know like five chickens had to die just so she could look that stupid'],
#  ['unfortunately yes', 'but you see thats okay wayne'],
#  ['we are half a million off', 'fuck it im not counting it again'],
#  ['fuck it im not counting it again',
#   'weight it if its sixty pounds its three if its fifty its two point five'],
#  ['mary mary im sorry ive got to go', 'come on george lets hurry'],
#  ['come on george lets hurry', 'did you get a doctor ?'],
#  ['and if i were in the comoros in the indian ocean where would you be ?',
#   'a few more moments still in this business then id find you'],
#  ['saturday night yes sir have a pleasant journey !',
#   'darling ! you will be careful ! ?'],
#  ['well hes a good soldier', 'i didnt mean that as a compliment'],
#  ['how sweet', 'my timing always was lousy'],
#  ['why else would you send off for me ? if you just wanted sex just go to a prostitute',
#   'well as it turns out i did'],
#  ['who is this paxcow ? is he like the boogeyman ?',
#   'hes a ghost but hes a good ghost'],
#  ['hes a ghost but hes a good ghost',
#   'there are no ghosts ellie i want you to go to sleep and forget all this nonsense'],
#  ['wed better go outside quickly', 'is there any chance ?'],
#  ['is there any chance ?', 'i guess theres always a chance'],
#  ['leave me alone !',
#   'you ve got to trust me it sounds silly but i know we were meant to meet'],
#  ['no just just give him give him ten thats it ten i ll be right down',
#   'hes gonna come up with ten thousand just the way you wanted'],
#  ['so talk', 'we think we got a rat in the house'],
#  ['no', 'of the woman in the mirror would you know her if you saw her ?'],
#  ['mazel tov !', 'hello mazel tov ! a boojee boojee boojee boo'],
#  ['hello mazel tov ! a boojee boojee boojee boo', 'im not finished yet mom'],
#  ['u you u put it in there', 'i may have said some thing i dont recall'],
#  ['i dont know what you are talking about im just driving',
#   'look what im doing is none of your business'],
#  ['look what im doing is none of your business',
#   'is alan baer the game ? is that what this is ?'],
#  ['yep', 'you didnt even hafta say it i know the woman'],
#  ['ssh hes great', 'peggy sues still stuck on treble without a cause'],
#  ['peggy sues still stuck on treble without a cause',
#   'i thought i knew everything about him'],
#  ['im adjusting okay', 'and your new apartment ?'],
#  ['why does this sound so familiar ?',
#   'assault on voltareck iii episode i think'],
#  ['assault on voltareck iii episode i think', 'we are doing episode ?'],
#  ['wow !', 'what just happened ?'],
#  ['what just happened ?', 'are you okay ?'],
#  ['arthur', 'lancelot i will save you dont die'],
#  ['lancelot i will save you dont die',
#   'my salvation is to die a knight of the round table'],
#  ['where is she ?', 'i can hear her oh mother of god i can hear her'],
#  ['i can hear her oh mother of god i can hear her', 'casey ! casey !'],
#  ['you bet we all cant be such modern people',
#   'come on mark mark ah hell why not i ll get the maid to write the essays'],
#  ['what ?', 'could ya take off that hat'],
#  ['its my own way it works for me i dont care about the rest of that stuff',
#   'then why are you here ?'],
#  ['your mothers murder was last years hottest court case somebody was gonna write a book about it',
#   'and it had to be you with all your lies and bullshit theories'],
#  ['no edgar allen', 'the furniture guy ?'],
#  ['you all right ethan ?', 'huh ? sure im all right'],
#  ['huh ? sure im all right',
#   'say ! what happened to your blanket ? lose it ?'],
#  ['the dirty yellow rat bastard',
#   'dont push it you way ahead you back on top that boy loves you man'],
#  ['dont push it you way ahead you back on top that boy loves you man',
#   'what you say ?'],
#  ['excuse me is this the buildings and grounds office ?',
#   'yeah can i help you ?'],
#  ['taiwan',
#   'not that i would know but you look like you are really good at it'],
#  ['you are not in a very good mood', 'you dont miss a thing'],
#  ['you living together ?', 'shes back in jersey going to graduate school'],
#  ['shes back in jersey going to graduate school', 'explain how that works'],
#  ['his name is chuckie roeder but somethings very weird',
#   'you found his mugshot ?'],
#  ['what the hell good is hooker to ya ?', 'hes gonna set up gondorff for us'],
#  ['damn', 'almost got me in billings i saw you there shooting at me'],
#  ['almost got me in billings i saw you there shooting at me',
#   'i went myself to oversee the operation didnt help much'],
#  ['yeah yeah right what the fuck are doing ? what the fuck are you doing in my house ?',
#   'dont yell honey please dont go crazy'],
#  ['dont yell honey please dont go crazy',
#   'im not crazy dont you tell me im crazy'],
#  ['so how did you find out i didnt do it ?',
#   'i didnt i just realized i already knew'],
#  ['i know ive felt it', 'im weak soon i ll need to feed'],
#  ['well just dont forget your old friends when you are rich and famous',
#   'are you kidding ? you guys ll he running this joint by then'],
#  ['you are anya rosson arent you ? ive heard of you back in new york',
#   'sorry i cant return the compliment'],
#  ['now what ?', 'ive never met anyone like you'],
#  ['nick hes fine hes in a hospital and they are fixing him up',
#   'you talk to him ?'],
#  ['you talk to him ?', 'oh sure twice a day'],
#  ['wed like to ask you some questions about daniel zavitz',
#   'who u are u you people ?'],
#  ['who u are u you people ?', 'im an investigator with pro tech security'],
#  ['the white reflects the sun it keeps you cooler thats why they wear them',
#   'think the iraqis killed them all ?'],
#  ['think the iraqis killed them all ?',
#   'probably shot a few scattered the rest murderers'],
#  ['nah not now i wanna wait i dont feel right',
#   'im tellin you she ll be there i know she ll be there'],
#  ['im tellin you she ll be there i know she ll be there',
#   'cause i wanna catch her alone'],
#  ['goodbye', 'you didnt deserve me john buckingham'],
#  ['i dont know why i just couldnt help it',
#   'but sooner or later we ve got to end this relationship and its better to do it right now'],
#  ['you lent it to me in like tenth grade',
#   'ive been looking all over for this'],
#  ['ive been looking all over for this', 'look at how cute i am !'],
#  ['whats bothering you madison ?',
#   'the pain is getting worse i need more aspirin'],
#  ['the pain is getting worse i need more aspirin',
#   'i cant give you anymore i ll talk to the doctor'],
#  ['you dont understand the wedding bands the wedding bands are in my wallet',
#   'okay so they were in your wallet and you left your wallet somewhere some bar christine ll understand'],
#  ['get your things',
#   'hiroshima ! shes going with us ? are you out of your mind'],
#  ['youd think they ve never seen a new toy before',
#   'well sure look at him hes got more gadgets on him then a swiss army knife'],
#  ['bob are you making friends with this man ?',
#   'im just bragging about how great you are im the luckiest man alive'],
#  ['have ya been to the celebrity room before ? with other uh clients ?',
#   'i dont think so its nice'],
#  ['i dont think so its nice',
#   'yeah well it depends on the artist you know jose feliciano ya got no complaints waiter !'],
#  ['i just saw joe hes here', 'well you dont have to be so dramatic about it'],
#  ['no', 'sorry ned guess i wasted your time see ya kid !'],
#  ['sorry ned guess i wasted your time see ya kid !',
#   'you are goin back with him ?'],
#  ['especially now', 'so ive been thinking a lot'],
#  ['nah you go on', 'i have to talk to evelyn and i want you to meet her'],
#  ['i have to talk to evelyn and i want you to meet her',
#   'some other time i dont feel like a party'],
#  ['bravo !',
#   'but i dont have that any more all thats left for me now is the room upstairs'],
#  ['i thought i saw', 'it looks like a branch'],
#  ['why ?', 'just you could look very heavy'],
#  ['just you could look very heavy', 'dont make conversation with me'],
#  ['he wrote this thing about his dick once and he read it in front of the whole class',
#   'id love to read that'],
#  ['you think he got my license plates ?', 'he looked too shaken up'],
#  ['what about ids ?', 'one to seven deal the face cards'],
#  ['all the facts you need are right in front of you',
#   'gimme a minute here i think ive got it'],
#  ['it was an earthquake and it was dark i have no idea',
#   'these look quite fresh'],
#  ['send him away', 'send him ? ma i cant its just come out here please i'],
#  ['mom not now ! i i dont know what to do',
#   'yes you do you have to go rescue all those people'],
#  ['yes you do you have to go rescue all those people',
#   'but im not a hero im nobodys heroine im nothing you ve said so yourself many times'],
#  ['im going alone this could be dangerous', 'okay my sweet good night'],
#  ['hed give me a job', 'he would take you on yes'],
#  ['how wonderful darling what does that mean for you ?',
#   'i ll be running it three days a week and'],
#  ['i ll be running it three days a week and',
#   'will you get time off to do that ?'],
#  ['he took it', 'gawd you look awful'],
#  ['are you and dr woodly engaged ?', 'who have you been talking to ?'],
#  ['who have you been talking to ?',
#   'what difference does that make ? is dr woodly going to be my father now ?'],
#  ['whats happening to me ? why am i getting so much weaker ?',
#   'because your body can only take so much of what they are putting you through'],
#  ['laura', 'my names frank and furthermore you came back to see me tonight'],
#  ['my names frank and furthermore you came back to see me tonight',
#   'what if it wasnt you that i came back to see ?'],
#  ['did you see that about the guy who chopped up his wife into a million pieces ?',
#   'how could i miss it ? the tv wont quit with that stuff'],
#  ['how could i miss it ? the tv wont quit with that stuff',
#   'they are gonna cook him'],
#  ['rode right into them screaming like a banshee', 'my little web did that ?'],
#  ['those aint cops',
#   'and they sure aint from the neighborhood figure sabus in there ?'],
#  ['you', 'i got what i paid for'],
#  ['well all the same im going to advise starfleet and get instructions',
#   'im sure starfleet would approve sir'],
#  ['im sure starfleet would approve sir',
#   'i know but lets do it by the book stand by on this channel go'],
#  ['no ! he was crazy i didnt he looked i thought',
#   'okay okay take it easy dont freak out on me'],
#  ['okay okay take it easy dont freak out on me',
#   'do you have a mirror ? its the best way to see if someones breathing'],
#  ['poppa joe you want me to go now ?', 'yeah thanks rocco see ya'],
#  ['like i always do ?', 'thass right just play it'],
#  ['look mirtha shes walking', 'she did that before'],
#  ['she did that before', 'no these are her first steps watch her'],
#  ['as the man said its in my nature', 'whats that supposed to mean ?'],
#  ['you didnt tell us you were coming ?', 'then how did you know ?'],
#  ['i was wrong i admit it my bad okay ? now lets just go back to the ship',
#   'i dunno nice breeze wide open spaces you know im startin to enjoy myself out here'],
#  ['i dunno nice breeze wide open spaces you know im startin to enjoy myself out here',
#   'are you fucking high again ? just listen to'],
#  ['what is the dead poets society ?', 'any group pictures in the annual ?'],
#  ['any group pictures in the annual ?', 'nothing no mention of it'],
#  ['i need you to get me paula', 'you want her right now ?'],
#  ['you want her right now ?',
#   'yes now find her shes somewhere in the building'],
#  ['i was in the middle of', 'being utterly fucking useless what else is new'],
#  ['two minutes til krieger shows thisll have to be quicker than id like certainly quicker than youd like',
#   'ethan if you knew about jim ? why'],
#  ['it was an accident gifford too',
#   'the portraits lasher why are the witches always before a door ? tell me lasher now !'],
#  ['why ?', 'to bring you your birthright'],
#  ['to bring you your birthright',
#   'my birthright ? you mean like a trust fund ?'],
#  ['and you wanted him to make a list !', 'will you let him tell it !'],
#  ['will you let him tell it !', 'she never wants to hear she doesnt care !'],
#  ['what do you mean ?', 'he means they are thieving dogs'],
#  ['charley charley wow', 'i wish i didnt have to do this terry'],
#  ['give it a rest you were thinking the same thing just didnt have the guts to take the heat',
#   'we can horsetrade with khruschev on ships but it doesnt get us any closer to removing those missiles'],
#  ['we can horsetrade with khruschev on ships but it doesnt get us any closer to removing those missiles',
#   'have to hope its a signal that he ll back down on the real issue too'],
#  ['you want to try with me ?', 'things cant get much worse can they ?'],
#  ['things cant get much worse can they ?', 'i dont see how'],
#  ['i heard someone crying a woman',
#   'a woman crying ? no ones been crying here'],
#  ['i dont like this i dont like this at all', 'oh they are so cute'],
#  ['what are you going to do ?',
#   'hes expecting my call im going to the station and im going to call him'],
#  ['yes', 'one of my men is down i want to know what happened to him'],
#  ['i know i dont know anything',
#   'exactly dont you wonder where im really hiding simone ?'],
#  ['exactly dont you wonder where im really hiding simone ?',
#   'im sure youd tell me if you thought it was important'],
#  ['long trip pretty nice of you to come',
#   'well im close to her i wanted to meet the one that got away'],
#  ['well what ?', 'have you decided ?'],
#  ['have you decided ?', 'all i said was that it sounds like a good idea'],
#  ['then what the fuck ?', 'hey you dont know that shit for sure'],
#  ['hey you dont know that shit for sure',
#   'oh jesus you are such a fuckin retard !'],
#  ['nobody told me ! nobody told me ! you sold all of our stock ?',
#   'we dumped the whole load now quit showboating addison'],
#  ['i dont know what he was thinking',
#   'oh for gods sake what has this guy got a horse fetish ?'],
#  ['heather chandler is one bitch that deserves to die',
#   'killing her wont solve anything'],
#  ['let me see the plant press', 'what is it ?'],
#  ['they only kill them when they love them ?',
#   'what are you doing here i thought you were a nazi'],
#  ['churchill degaulle disraeli they all went through the pain of losing power',
#   'but they all got it back again didnt they ? we should have lunch sometime'],
#  ['yeah i know', 'are you ok ?'],
#  ['zero c mon dan i dont have all day', 'got a pencil ?'],
#  ['got a pencil ?', 'just give it to me i ll remember'],
#  ['didnt kill anything did i ?',
#   'a few rabbits but i think one of them was already dead'],
#  ['a few rabbits but i think one of them was already dead',
#   'that would explain the indigestion'],
#  ['how long was i out ?',
#   'three days i was worried about you how are you feeling ?'],
#  ['my people have a strict policy of non interference with other cultures in fact its our prime directive',
#   'your directive apparently doesnt include spying on other cultures'],
#  ['i never could count on you to be reasonable dont force me to make an adjustment around here',
#   'cobb you ve got nothing i need'],
#  ['cobb you ve got nothing i need',
#   'im not thinking about your future paden im worried about stella'],
#  ['sorry', 'hey its okay i like to pee so how are you doing ?'],
#  ['you wanted to be partners with me ?', 'sure itd be fun'],
#  ['why wasnt i involved from the beginning ? you and i started fight club together',
#   'fight club was the beginning now its out of the basements and theres a name for it project mayhem'],
#  ['i ll have to perform one of my operations !',
#   'no o o dont touch her ! no !'],
#  ['what report ?', 'you mean you dont know ?'],
#  ['we are locked in', 'are you insane ? he ll kill us both !'],
#  ['are you insane ? he ll kill us both !', 'maybe its better that way'],
#  ['you must have a bible in here dont cha ?', 'yeah we got a bible'],
#  ['yeah we got a bible', 'get it and bring it up here will ya please ?'],
#  ['ah my dear friend come in come in please sit down',
#   'im sorry i was at the theater and i didnt receive your note until i returned to my hotel'],
#  ['i cant its yours', 'take it damn it !'],
#  ['jes like in the catalogues aint they !', 'i seen em b fore you did'],
#  ['proper ? !', 'its against my programming to impersonate a deity'],
#  ['i guess i cut pretty loose in my day too',
#   'really frank ? when was that ?'],
#  ['really frank ? when was that ?', 'listen cant you wait till we get home ?'],
#  ['why ?', 'i wanted to use your car'],
#  ['her names libbets', 'libbets ? what kind of a name is libbets ?'],
#  ['libbets ? what kind of a name is libbets ?', 'the turkey in ?'],
#  ['im working for his daughter', 'that right ? she used to be some looker'],
#  ['yeah', 'how long you been up there fink ?'],
#  ['how long you been up there fink ?', 'a week eight nine days'],
#  ['its fine', 'they could put you in jail'],
#  ['kind of trouble im in the mood for',
#   'oh oh maybe i better get back in the truck'],
#  ['bastard you are going to need another nose !',
#   'but im not the type of guy to hold a grudge'],
#  ['had dinner at a place called the kings table buffet style it was pretty darn good',
#   'was it reasonable ?'],
#  ['now remember dont tell anybody we saw the terrance and phillip movie !',
#   'yeah lets swear we wont tell !'],
#  ['so pee ? here ?',
#   'yeah whip it out you want me to see it thats what this is all about right ?'],
#  ['yero by himself ?', 'maybe maybe with the crazy whites'],
#  ['tribuus tomorrow', 'you are coming back ?'],
#  ['what are you saying we cant stop whats out there ?',
#   'what the hell ? it shut us down'],
#  ['what the hell ? it shut us down', 'jerry ? please stop this'],
#  ['jesus holly we got enough time', 'okay but i dont want to miss him'],
#  ['okay but i dont want to miss him', 'follow that budjovice sign'],
#  ['yes laddie i have her', 'should i care ?'],
#  ['talk to me in the morning i feel like shit', 'but it cant wait'],
#  ['will you stop squawking !', 'look at me look at what they gave me to wear'],
#  ['no way man youd rob me blind !',
#   'but maybe its not so healthy being so close you know to a school'],
#  ['i cant do it jani',
#   'im asking you as a friend youd be saving the life of a friend'],
#  ['wait listen to me pappas if you dont let us by',
#   'we are all gonna die in this'],
#  ['my little niece she got this deep cough', 'you take her to a doctor ?'],
#  ['thats the building she lives on the seventh floor dont stop to look long the police are watching',
#   'where are they ?'],
#  ['where are they ?',
#   'i dont know you are not supposed to see them they are supposed to see you'],
#  ['you are as bad as harry', 'i ll go i ll go'],
#  ['really ?', 'you are going to blow everyone away'],
#  ['you cant tell anybody about this',
#   'i know i know but im saying if they knew we are going to be millionaires man millionaires !'],
#  ['we changed our minds', 'i got you a present'],
#  ['i got you a present', 'but i didnt get you one'],
#  ['when did you decide ?',
#   'its been a long time coming i finally made up my mind i guess it was thursday'],
#  ['its been a long time coming i finally made up my mind i guess it was thursday',
#   'hi im max cherry your bail bondsman'],
#  ['thats a lollipop that boy the kid is only great',
#   'and with ten percent of his future you are great too frank'],
#  ['and with ten percent of his future you are great too frank',
#   'went over to philly yesterday an seen the folks its nice you send them the fifty a month'],
#  ['lenny my dispatcher',
#   'i know you are out there ! answer the goddamn call !'],
#  ['i know you are out there ! answer the goddamn call !',
#   'what happens if you dont ?'],
#  ['nothing completely conclusive',
#   'i hope to we are working to develop this evidence'],
#  ['it takes all types', 'so whos he ?'],
#  ['so whos he ?', 'hes what she should run a mile from'],
#  ['i hope so hundred bucks apiece is a lot of dinero',
#   'what time are we supposed to get to the hotel ?'],
#  ['well there goes our record deal', 'nah we still got billy bob'],
#  ['you doing okay ?', 'got a job at old franks place his son runs it now'],
#  ['got a job at old franks place his son runs it now',
#   'oh man that kid takes himself real serious'],
#  ['ohh ! i wanted to sit next to leif',
#   'shut up you there you there and you there'],
#  ['you put me in an awkward position mr kessler', 'how is that ?'],
#  ['last present !',
#   'its a big one its a its a boardgame ! repeat ! battleship battleship the boardgame !'],
#  ['nowhere ? im here', 'for how long ?'],
#  ['for how long ?', 'oh i hope a long long time'],
#  ['they respond pretty quick i ll wait till you get down before i turn it on',
#   'good see ya soon'],
#  ['why ask me ?', 'because you are a pirate'],
#  ['because you are a pirate', 'and you want to turn pirate yourself ?'],
#  ['no',
#   'good it would be most unfortunate if i had to leave a permanent garrison here'],
#  ['yeah', 'it feels like you are in france'],
#  ['the world wants winners i guess not people stained with loserness',
#   'stained with loserness oh i like it can i use that itd be dynamite on interoffice memoranda'],
#  ['stained with loserness oh i like it can i use that itd be dynamite on interoffice memoranda',
#   'its all yours heather now if you ll excuse me im going to go throw up'],
#  ['morning', 'i wonder if you could help me'],
#  ['can india help us ?',
#   'india is a newly independent nation they are struggling india is in no position to help us'],
#  ['im not gonna quit cause of one creepy phone call george',
#   'come on erin a jobs supposed to pay your bills not put you in danger'],
#  ['so ?', 'so got the keys to heaven baby'],
#  ['yeah steve steve was all right for awhile',
#   'all right for awhile ? the guys good looking rich witty he was a god'],
#  ['what are you doing ?',
#   'well its a five minute walk or a thirty second drive'],
#  ['well its a five minute walk or a thirty second drive',
#   'you had better be careful'],
#  ['you invited me', 'only if you are a good man a friend are you a friend ?'],
#  ['this is humiliating we are being ejected from a prom !',
#   'hang in there i ll think of something'],
#  ['should i call you later ?', 'i ll just see you when you get back here'],
#  ['who is frank ?', 'a six foot tall bunny rabbit'],
#  ['well i suppose it would be all right for just a little while',
#   'would you like a sandwich ?'],
#  ['would you like a sandwich ?', 'no thanks ! i want to get right to sleep'],
#  ['third floor spare bedroom den what have you mr pearlstine used it as an office',
#   'hes talking about bernard pearlstine'],
#  ['yes james is very sweet why dont you get out your violin donna ?',
#   'sweet ? god hes gorgeous'],
#  ['lets ride', 'i am so sorry jesse'],
#  ['arent you giving an exam ?', 'i said dont worry about it'],
#  ['as surely as if it were my own ! harry give me back the enterprise ! with scottys help',
#   'no jim ! enterprise would never stand the pounding'],
#  ['no jim ! enterprise would never stand the pounding',
#   'then i ll find a ship i ll hire a ship'],
#  ['whos that ?', 'biff martin captain of the basketball team'],
#  ['biff martin captain of the basketball team', 'does he you know like me ?'],
#  ['you see ? life can be so simple', 'for twelve francs seventy five'],
#  ['george', 'hey baby say hello to felicia'],
#  ['hey baby say hello to felicia', 'i already said hello'],
#  ['why ?', 'i dont know you just are leaving a light for plato that was nice'],
#  ['boy holly holly',
#   'i just want a salad you really think im a loser dont you ?'],
#  ['i just want a salad you really think im a loser dont you ?',
#   'what do ? you are being ridiculous'],
#  ['thanks', 'most fun ive had all day'],
#  ['most fun ive had all day', 'you need to get out more'],
#  ['we arent completely stupid',
#   'stay in the light ! everybody ! stay in the fucking'],
#  ['stay in the light ! everybody ! stay in the fucking',
#   'we crossed our own tracks'],
#  ['what happened to you ?', 'i had a little run in with zowie'],
#  ['what ? my eyes are not lying !',
#   'yes they are josh since mankato they have been lying eyes'],
#  ['okay thanks', 'nice to know they cant seem to get along without ya'],
#  ['how violated i feel ?', 'you are not the only one'],
#  ['i warned you about playing that shit when im in the car',
#   'that was my cd dont you ever touch a chinese mans cd'],
#  ['waal mr moss i wouldnt',
#   'you wouldnt be here if it wasnt true its true right ?'],
#  ['no course not', 'hows it going ?'],
#  ['hows it going ?', 'great we got one of em'],
#  ['thanks', 'betsy come over here a moment'],
#  ['betsy come over here a moment', 'what is it ? im busy'],
#  ['i was wrong about you and u im u sorry',
#   'is that what you came here to say ?'],
#  ['is that what you came here to say ?',
#   'mainly and also that im proud very proud to be your son'],
#  ['claim ? oh claim thats what thomas asked me', 'thomas ? whos thomas ?'],
#  ['thomas ? whos thomas ?', 'thomas franklin an attorney'],
#  ['it was great for me how was it for you', 'a bit too quick'],
#  ['a bit too quick',
#   'well now we can do it slow are those some kind of stockings you are wearing ?'],
#  ['i think sometimes mrs little candor is the only kindness',
#   'all of your children are delinquent mrs little and one at least malcolm is a thief'],
#  ['what does time travel have to do with philosophy ?',
#   'guess who wrote it ?'],
#  ['i mean breakfast',
#   'yeah sure and i bet you had lobster last night along with two bottles of champagne'],
#  ['yeah sure and i bet you had lobster last night along with two bottles of champagne',
#   'just one bottle i believe in moderation'],
#  ['hows your shoulder ?', 'fine hows your back ?'],
#  ['you go boy',
#   'if its all the same to you id rather not dish right here in the middle of crankville'],
#  ['if its all the same to you id rather not dish right here in the middle of crankville',
#   'feeling the paranoia tonight are we ?'],
#  ['which question is that ?',
#   'the one you came up to ask are we on schedule ?'],
#  ['the one you came up to ask are we on schedule ?',
#   'take note mr mason this is why you hire a professional no whining no excuses'],
#  ['hi i brought some wine', 'thank you wont you come in ?'],
#  ['all right',
#   'uh huh mi raccomando italian american slang for im counting on you'],
#  ['what ?', 'talk about it right now i mean i got to um'],
#  ['communist viet cong', 'they left it in the jungle'],
#  ['and how is lord lavenham ?', 'and little lady beatrice ?'],
#  ['i dont suppose theres a drink left', 'you can have one at maxs'],
#  ['you can have one at maxs', 'i dont think im going'],
#  ['what ?', 'not u they u u he u'],
#  ['tell me about yourself', 'which part ? that or the day to day'],
#  ['which part ? that or the day to day',
#   'lets keep it the day to day stuff hows kevin ?'],
#  ['take it easy',
#   'theres no time to take it easy ! you dont realize the diabolical mind we are dealing with !'],
#  ['please sir', 'ive never ridden in an automobile'],
#  ['ive never ridden in an automobile',
#   'i assure you sir david is a very careful driver please wont you let us take you ?'],
#  ['dont tell me you are waiting for lightning to strike wide eyed romantics are an endangered species',
#   'that sounds kind of pessimistic'],
#  ['that sounds kind of pessimistic',
#   'no realistic theres no magic in the world girls just dont get swept off their feet anymore'],
#  ['you got me beat on both accounts', 'the hell i do'],
#  ['the hell i do', 'gabriel ? are you asleep ?'],
#  ['yeah a toon it was the guy who killed bambis mother',
#   'him ? oh he was vile heinous despicable a smear on the drafting board'],
#  ['but she is real it wasnt just a concussion',
#   'forget her you are mine i saw you first'],
#  ['the word of god', 'no henry try not to talk'],
#  ['no henry try not to talk', 'the name of god'],
#  ['its for wheat we ve always grown maize in the strip above the vegetables',
#   'and in the vegetable plot ?'],
#  ['yes sir', 'i am lieutenant dunbar'],
#  ['i am lieutenant dunbar', 'what is your number ?'],
#  ['hes not slowing', 'hes going to slow down'],
#  ['stay ? they lived together all their years ?', 'oh yes i think'],
#  ['so ? what do you think ? you think you are the one ?',
#   'honestly ? i dont know'],
#  ['she was a liar she was a liar !',
#   'answer my question ! werent you paid to get out of town ?'],
#  ['i dont', 'how did you meet him ?'],
#  ['how did you meet him ?',
#   'on a train he said he lived here and he offered to make a reservation for me'],
#  ['is it ever embarrassing having your bum kissed in public ?',
#   'if your ass isnt chapped you are not a good writer of note'],
#  ['so why are you even considering it ? are you ?', 'just like you would be'],
#  ['sounds great where do i sign up ?', 'i havent been out here for a while'],
#  ['i havent been out here for a while', 'you go by your old house ?'],
#  ['looks like a design some writing maybe maybe it was sent to meet the spacecraft with a message',
#   'look closely that isnt writing those are grooves'],
#  ['look closely that isnt writing those are grooves',
#   'no they dont represent a message they arent decorative at all they have another purpose entirely'],
#  ['woody ? ! what are you doing ?', 'hold still buzz !'],
#  ['yeah mack ?', 'captain this is some spooky shit we got here'],
# ...
#   'code ive heard a lot about this'],
#  ['i am', 'thats a big help where are you from ?'],
#  ['yes', 'and you didnt send her to a doctor'],
#  ['and you didnt send her to a doctor', 'i didnt guess until it was too late'],
#  ['just come to the mudd club on friday',
#   'i dont go there too many party girls'],
#  ['i dont go there too many party girls', 'party girls ? can i call you ?'],
#  ['any way fate stepped in and took football out of the equation',
#   'and everyone lived happily ever after'],
#  ['ive got nothing to say to you', 'you know what happened'],
#  ['what ?', 'hello can you hear me now ?'],
#  ['hello can you hear me now ?', 'whats happening ? !'],
#  ['no no thats ray here ray uh ray little weasel',
#   'leos gotta get to burial brother hes gotta make the journey'],
#  ['oh', 'you may not remember things'],
#  ['well if its already too late',
#   'its never too late give those cigarettes back now and buy some gum instead here chewlies gum try this'],
#  ['your wife ?',
#   'shes gone and the present is trivia which i can scribble down as notes'],
#  ['no', 'why didnt you tell me ? why didnt you hold him ?'],
#  ['you cant come to southern italy and not see the blue grotto',
#   'i just need to run up and get my bathing suit'],
#  ['i just need to run up and get my bathing suit',
#   'okay i ll meet you at the dock in ten minutes'],
#  ['oh how beautiful !',
#   'it reminded me of you so i bought it it cost me more than all the others'],
#  ['it reminded me of you so i bought it it cost me more than all the others',
#   'i shall wear it in my hair !'],
#  ['i understand that you had a rather unfortunate encounter with the police tonight',
#   'yes sir i suppose you might call it that sir'],
#  ['yes sir i suppose you might call it that sir',
#   'hahaha and how are you feeling now ?'],
#  ['seventeen minutes',
#   'armor up sick sticks and concussion guns this is gonna be close'],
#  ['everybody has one like that i thought it was great when you started to laugh at the end',
#   'yeah well im sorry im tying up jane i didnt realize you two would be going this late sorry'],
#  ['yeah well im sorry im tying up jane i didnt realize you two would be going this late sorry',
#   'no dont worry about it'],
#  ['that was my choice nothing to do with you i took a chance and it didnt work out',
#   'bluebell came in ?'],
#  ['im into garbage its my thing',
#   'boy this is really a nice screening room its really a nice room'],
#  ['they got a sign on him says he was a killer', 'a sign on him ?'],
#  ['no i see her around the pool i know her i know her like that not like that',
#   'nah not now i wanna wait i dont feel right'],
#  ['nah not now i wanna wait i dont feel right',
#   'im tellin you she ll be there i know she ll be there'],
#  ['funny so am i',
#   'congratulations unfortunately my train is about to leave and i really must insist you disembark'],
#  ['looks like you did more than jackoff while i was gone',
#   'maybe are animating you wasnt such a bright idea you look like shit'],
#  ['why terry who said it was ?',
#   'well nobody i guess but that father barry i didnt like the way he kept lookin at me'],
#  ['well nobody i guess but that father barry i didnt like the way he kept lookin at me',
#   'he was looking at everybody the same way asking the same question'],
#  ['did we create his mind too ? not only can this man speak he can write he can reason',
#   'he can reason ? with the tribunals permission let me expose this hoax by direct examination'],
#  ['he can reason ? with the tribunals permission let me expose this hoax by direct examination',
#   'proceed but dont turn this hearing into a farce'],
#  ['people are talking they say the yakuza has a contract out on you',
#   'i hear that shit once a week dont worry jo jo bao loves me'],
#  ['yeah how did you know ?',
#   'i just know thats all i remember you from central'],
#  ['no no no no no', 'the kind of man that could have killed edie finneran'],
#  ['let him go', 'that son of a bitch dont get me wrong hes a fine writer'],
#  ['that son of a bitch dont get me wrong hes a fine writer',
#   'i ll jus walk on down to the pacific and from there i ll improvise'],
#  ['i ll keep that in mind', 'we are in business'],
#  ['we are in business', 'good work flynne you are a first rate rat'],
#  ['go ahead', 'no nothing ive got a problem i guess'],
#  ['no nothing ive got a problem i guess',
#   'were you bothering by those waitresses making a fuss ?'],
#  ['by my head here come the capulets', 'by my heel i care not'],
#  ['by my heel i care not',
#   'follow me close gentlemen gooday a word with one of you ?'],
#  ['now that is very interesting take a chair joseph',
#   'can anyone hear what we say ?'],
#  ['you werent at my game',
#   'yeah sorry about that i had this meeting with this guy'],
#  ['yeah sorry about that i had this meeting with this guy',
#   'yeah i hit a three at the buzzer'],
#  ['really ?', 'i could pencil you in if you like ?'],
#  ['i could pencil you in if you like ?', 'i ll take a rain check for now'],
#  ['any idea what he did ?',
#   'oh the scuttlebutt for awhile was he was investigating kennedy'],
#  ['hier sind fruher fursten ans unt eingeganger hier hat sogar ein metternich verkehrt',
#   'give her some cigarettes'],
#  ['watch your mouth',
#   'monica i think her point is maybe its time to start thinking about other things besides basketball'],
#  ['but i am history',
#   'of course your highness nevertheless cure the marquis de sade succeed where countless physicians and priests have failed'],
#  ['huh ?', 'you met the gift'],
#  ['draw', 'whats your record at ?'],
#  ['not yet', 'i ll be forced to tickle you'],
#  ['rosa',
#   'well what if this guys just playing with you ? what if hes lying about who he is ?'],
#  ['i ll tell you the problem you behind the wheel theres your fucking problem',
#   'thats pretty simplistic dont you think ?'],
#  ['could we sit down someplace ?',
#   'im sorry ive had you on your feet for hours'],
#  ['no i dont think so',
#   'well think because theres footprints here that arent mine'],
#  ['well think because theres footprints here that arent mine',
#   'well they are not mine'],
#  ['so ?', 'you want to take a look at my car ? i think the radiator hose is'],
#  ['i have a plan if it succeeds then any battle will be decidedly brief and one sided',
#   'whats your plan ?'],
#  ['not at all', 'sure you want to keep those in the house ?'],
#  ['sure you want to keep those in the house ?',
#   'im so sorry about that it was rude i think i just got nervous for some reason'],
#  ['hey they are ralph laurens and whos this interesting looking fellow ?',
#   'this is adam adam meet cliff'],
#  ['this is adam adam meet cliff', 'how do you do ?'],
#  ['im hungry',
#   'take your choice ive got enough so we wont have to go out of the house till tuesday'],
#  ['take your choice ive got enough so we wont have to go out of the house till tuesday',
#   'what did all this stuff cost you ?'],
#  ['oh yes ? and whats so intelligent about writing a requiem ?',
#   'money ! money !'],
#  ['money ! money !', 'you are mad ! shes mad wolfi'],
#  ['dont worry i plan to have something within twenty four hours john',
#   'how the hell are you going to do that ?'],
#  ['hi there little brother', 'say hi to paul'],
#  ['what are you askin me for put em in the first helicopter comes in tomorrow',
#   'nobody comes in here'],
#  ['i wont talk about the other two',
#   'but they both worked at the white house ?'],
#  ['but they both worked at the white house ?',
#   'i will not talk about the other two'],
#  ['i can see and you also brought a nice girl to come eat by us',
#   'so do you have a name ?'],
#  ['majesty',
#   'delightful court composer would you permit me to play it as he comes in ?'],
#  ['delightful court composer would you permit me to play it as he comes in ?',
#   'you do me too much honour sire'],
#  ['neither had i odd desire for a woman i guess', 'odd desire for anyone'],
#  ['round the world in eighty days hello kris',
#   'you are amazing what are you doing mr parker ?'],
#  ['have you ever talked to carl tried to see his side ?',
#   'his side ? ive seen it all right a nice bright yellow !'],
#  ['hmm nice',
#   'its really pretty outside how about taking me for a walk after you ve finished your breakfast ?'],
#  ['its really pretty outside how about taking me for a walk after you ve finished your breakfast ?',
#   'oh i suppose i oughta try to do some writing first'],
#  ['im just resting my feet',
#   'remember the first round how i had him against the ropes and'],
#  ['remember the first round how i had him against the ropes and',
#   'i ll never forget it i thought it was all over'],
#  ['the movers', 'yes i know this path louis ? where does it go ?'],
#  ['yes i know this path louis ? where does it go ?',
#   'i dont have the slightest idea when i saw the house this field was under four feet of snow'],
#  ['i rat cecile out to mommy mommy goes ballistic and ends their relationship boo hoo',
#   'but who will they turn to for help ?'],
#  ['hes developing a hemisphere imbalance', 'talk so i can understand'],
#  ['some hollywood movie star her plane got in late',
#   'discouraging isnt it ? women with furs like that where it never gets cold'],
#  ['im not rambling', 'you are talking like a madman'],
#  ['have you been in boulder long mrs torrance ?',
#   'only about three months eh we are from vermont my husband was teaching school there'],
#  ['what do you want me to start with the golden gate bridge ?',
#   'now i look up i look down i look up i look down nothing to it'],
#  ['now i look up i look down i look up i look down nothing to it',
#   'stop kidding wait a minute'],
#  ['well try huh',
#   'i dont know if i can its just that war is war things happen'],
#  ['is there anything you do know ?', 'i know you are a pussy i know that'],
#  ['i know you are a pussy i know that', 'all right lets get out of here'],
#  ['yes why do you think you woke and they didnt ?',
#   'i dont know maybe im a light sleeper'],
#  ['i dont know maybe im a light sleeper',
#   'loks like you had a break in up here as well'],
#  ['just relax', 'i dont need to relax the woman put her on'],
#  ['i dont need to relax the woman put her on', 'you ll see her'],
#  ['only at the very end', 'how do you feel after a shooting'],
#  ['how do you feel after a shooting', 'like it had to be done'],
#  ['are we going to argue ?',
#   'id love to argue with you sometimes but you are never here !'],
#  ['id love to argue with you sometimes but you are never here !',
#   'perhaps i was never meant to live with a woman'],
#  ['wait its nancy',
#   'im sorry but you could ve been the one doing all of this'],
#  ['chekov who is this man ?',
#   'a criminal captain a product of the late th century genetic engineering'],
#  ['a criminal captain a product of the late th century genetic engineering',
#   'what do you want with us ? i demand'],
#  ['whoa whoa come on hes making too much noise',
#   'you hear that bitch ? be quiet !'],
#  ['what are you doing in the ship ? beth ?',
#   'getting food we were out of food whats wrong ? you sound mad'],
#  ['getting food we were out of food whats wrong ? you sound mad',
#   'yeah well i get that way when im facing death and someone deserts me'],
#  ['im not sure i know you well enough i dont think im comfortable',
#   'yo im not comfortable either'],
#  ['i am uncertain', 'spock im really tired'],
#  ['that so', 'all i wanted him to do was let mickey out for christmas'],
#  ['all i wanted him to do was let mickey out for christmas',
#   'who is mickey ?'],
#  ['i know about that shot a terrible tragedy how much do you have for carrying on your investigation ?',
#   'if you must know virtually nothing'],
#  ['we are not yet open for business im afraid',
#   'shame i was recommended by a friend'],
#  ['nobody u lives u on this lake its really u his u lake now',
#   'c mon hector i know you are crazy but you cant'],
#  ['c mon hector i know you are crazy but you cant',
#   'i need to see his habitat'],
#  ['no', 'how do you know ?'],
#  ['rekallrekallrekall you thinkin of goin there ?', 'i dont know maybe'],
#  ['my god what the hell are you ?', 'hurry the woman needs help !'],
#  ['why dont i ?', 'no no no no no no wait'],
#  ['i cant write anything by tomorrow',
#   'who said write ? jesus jack cant read you gotta tell it to him tell him something for chrissake'],
#  ['im sorry im late', 'whats the hurry ?'],
#  ['we cannot break free captain we do not have a fraction of the power necessary',
#   'delay that order scotty ! disengage all main drive systems !'],
#  ['i told you', 'you tell me again'],
#  ['yeah lloyd what are your plans for the future ?',
#   'spend as much time as possible with diane before she leaves'],
#  ['is he out ?', 'like the rock of gibraltar'],
#  ['fuckin a',
#   'sorry about that pete but tailgating is one thing i cant tolerate'],
#  ['mirrors', 'luckiest guy in the northern fucking hemisphere is all ims'],
#  ['luckiest guy in the northern fucking hemisphere is all ims',
#   'what ? because im a little understand'],
#  ['how ?',
#   'well it still sucks but you start to see that there are advantages to being single'],
#  ['where could he have gone ?',
#   'maybe he got some definite lead maybe he went right on'],
#  ['what is it this time ?',
#   'a man came by the house a psychiatrist by the name of loomis'],
#  ['remember phillippe nobility is born in the heart',
#   'hold your goblet with two fingers'],
#  ['what did i get ?', 'yeah what vibe ?'],
#  ['yeah what vibe ?',
#   'i detected no vibe other than that ruiz thinks you are a fucking idiot'],
#  ['if hes nuts why doesnt the state just put him away ?',
#   'because it happened to be a colored policeman'],
#  ['because it happened to be a colored policeman',
#   'the colored vote happens to be very important to the mayor of this town'],
#  ['who wrote this book ?',
#   'scientists who have been persecuted for their beliefs'],
#  ['scientists who have been persecuted for their beliefs',
#   'that means they are unemployed'],
#  ['here we go again',
#   'you know women normally change five times more than men'],
#  ['you know women normally change five times more than men',
#   'you get that off the screen ?'],
#  ['i still am', 'is that right ?'],
#  ['this is not going well', 'hurry ! queen cherlindrea will know what to do'],
#  ['we are going to lose', 'you cant know that for sure'],
#  ['been better i read about whats been happening with you i should have called',
#   'what kind of trouble are you in ?'],
#  ['thank you sir',
#   'let us remember this night and tell the world that even in hell there are good people'],
#  ['no ! dont kill him !', 'it john not him it'],
#  ['it john not him it', 'alright it ! we need it !'],
#  ['yeah well',
#   'its just my stupid way of getting attention ! god i practically love you josh !'],
#  ['ambulance', 'we are just gonna take some blood here'],
#  ['dont you think we should at least pull over and offer to clean it off ?',
#   'what ? ! are you mentally deranged jam ?'],
#  ['we appreciate your help with this', 'so whats the deal ?'],
#  ['no', 'what about guinan ? what has she told you about me ?'],
#  ['what about guinan ? what has she told you about me ?',
#   'guinan ? i dont know what you are talking about'],
#  ['we are not saying anything about that night to the police we should all forget that night',
#   'what happened to me ?'],
#  ['atlantic city ?',
#   'i know its a drag but you cant find a hotel room in town not on new years eve'],
#  ['i need to know', 'you need to know what ? do i still love you ?'],
#  ['hi baby ive missed you',
#   'i know lenny if tran finds you talking to me he ll hurt you'],
#  ['i can explain', 'sure ! you are never at a loss for words'],
#  ['thats the one whatever happened to him ?',
#   'he pulled it on rorschach and rorschach dropped him down an elevator shaft'],
#  ['pardon ?', 'oh no mrs robinson oh no'],
#  ['what about our grenades ?',
#   'those are tigers they have six inch armor they dont even notice grenades'],
#  ['the sounds but not the language we would be responding in gibberish',
#   'is there any other planet where this species exists ?'],
#  ['is there any other planet where this species exists ?',
#   'the humpback was indigenous to earth earth of the past'],
#  ['i saw the show', 'well maybe it works on fingers too'],
#  ...]

# %%
mx_sent_30_min_sent_1_min_wrd_10_dim50 = (index2word, word2index, embedding, final_pairs, vocab_size)

# %%
pickle.dump(mx_sent_30_min_sent_1_min_wrd_10_dim50, open( "saved_pickle/mx_sent_30_min_sent_1_min_wrd_10_dim50.p", "wb" ) )

# %%
index2word, word2index, embedding, final_pairs, vocab_size  = \
pickle.load( open( "saved_pickle/mx_sent_30_min_sent_1_min_wrd_10_dim50.p", "rb" ) )

# %% [markdown]
# ## Makesure the GloVe vectors work the way they are supposed to

# %%
np.dot(embedding[word2index["admire"]],embedding[word2index["respect"]])
# Out:
# 12.615147

# %%
np.dot(embedding[word2index["admire"]],embedding[word2index["sad"]])
# Out:
# 8.450459

# %%
np.dot(embedding[word2index["sad"]],embedding[word2index["depressed"]])
# Out:
# 12.561041

# %%
##########  Converts [" input string ", " output string "] (pair) , appends <EOS> index and returns indices ######

def indexesFromSentence(lang, sentence):
    '''
    account for strings not in the vocabulary by using the unknown token
    '''
    sentence_as_indices = []
    for word in sentence.split(' '):
        if word in lang.word2index:
            sentence_as_indices.append(lang.word2index[word])
        else:
            sentence_as_indices.append(lang.UNK_token)
    
    return sentence_as_indices


def variableFromSentence(lang, sentence):
    indexes = indexesFromSentence(lang, sentence)
    indexes.append(lang.EOS_token)
    result = Variable(torch.LongTensor(indexes).view(-1, 1))
    if use_cuda:
        return result.cuda()
    else:
        return result


def variablesFromPair(pair,lang):
    input_variable = variableFromSentence(lang, pair[0])
    target_variable = variableFromSentence(lang, pair[1])
    return (input_variable, target_variable)

######## the pair indices are returned as 2 LongTensor Variables in torch #############


######## Tells you how long youve been training and how much longer you have left ####

import time
import math


def asMinutes(s):
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)


def timeSince(since, percent):
    now = time.time()
    s = now - since
    es = s / (percent)
    rs = es - s
    return '%s (- %s)' % (asMinutes(s), asMinutes(rs))

######################################################################3

############### plot_losses #######################################

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import numpy as np


def showPlot(points):
    plt.figure()
    fig, ax = plt.subplots()
    # this locator puts ticks at regular intervals
    loc = ticker.MultipleLocator(base=0.2)
    ax.yaxis.set_major_locator(loc)
    plt.plot(points)
    
####################################################################

# %%
class EncoderRNN(nn.Module):
    
    def __init__(self, hidden_size, embedding,
                 num_layers = 3, bidirectional = False, train_embedding = True):
        
        super(EncoderRNN, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.bidirectional = bidirectional
        embedding = torch.from_numpy(embedding).float()
        self.embedding = nn.Embedding(embedding.shape[0], embedding.shape[1])
        self.embedding.weight = nn.Parameter(embedding, requires_grad=train_embedding)
        self.gru = nn.GRU(embedding.shape[1], hidden_size, num_layers, bidirectional=bidirectional)
        
        if bidirectional:
            num_directions = 2
        else:
            num_directions = 1
        
        # make the initial hidden state learnable as well 
        hidden0 = torch.zeros(self.num_layers*num_directions, 1, self.hidden_size)
        
        if use_cuda:
            hidden0 = hidden0.cuda()
        else:
            hidden0 = hidden0

        self.hidden0 = nn.Parameter(hidden0, requires_grad=True)

    def forward(self, input, hidden):
        embedded = self.embedding(input).view(1, 1, -1)
        output = embedded
        output, hidden = self.gru(output, hidden)
        
        if self.bidirectional:
            output = output[:, :, :self.hidden_size] + output[:, : ,self.hidden_size:] # Sum bidirectional outputs
            
        return output, hidden

    def initHidden(self):
        
        if use_cuda:
            return self.hidden0.cuda()
        else:
            return self.hidden0

# %%
class AttnDecoderRNN(nn.Module):
    
    def __init__(self, hidden_size, embedding, dropout_p=0.1,  
                 num_layers = 3, train_embedding = True, max_length=30):
        
        super(AttnDecoderRNN, self).__init__()
        
        self.hidden_size = hidden_size
        self.dropout_p = dropout_p
        self.max_length = max_length
        self.num_layers = num_layers
        embedding = torch.from_numpy(embedding).float()
        self.embedding = nn.Embedding(embedding.shape[0], embedding.shape[1])
        self.embedding.weight = nn.Parameter(embedding, requires_grad=train_embedding)
        
        self.attn = nn.Linear(self.hidden_size + embedding.shape[1], self.max_length)
        
        self.attn_combine = nn.Linear(self.hidden_size + embedding.shape[1], self.hidden_size)
        
        self.dropout = nn.Dropout(self.dropout_p)
        self.gru = nn.GRU(self.hidden_size, self.hidden_size, num_layers = num_layers)
        self.out = nn.Linear(self.hidden_size, embedding.shape[0])
        
        hidden0 = torch.zeros(self.num_layers, 1, self.hidden_size)
        
        if use_cuda:
            hidden0 = hidden0.cuda()
        else:
            hidden0 = hidden0

        self.hidden0 = nn.Parameter(hidden0, requires_grad=True)

    def forward(self, input, hidden, encoder_outputs):
        
        embedded = self.embedding(input).view(1, 1, -1)
        embedded = self.dropout(embedded)

        cat = torch.cat((embedded[0], hidden[0]), 1)
        attn = self.attn(cat)
        
        attn_weights = F.softmax(attn, dim=1)
        
        attn_applied = torch.bmm(attn_weights.unsqueeze(0),
                                 encoder_outputs.unsqueeze(0))

        output = torch.cat((embedded[0], attn_applied[0]), 1)
        output = self.attn_combine(output).unsqueeze(0)

        output = F.relu(output)
        output, hidden = self.gru(output, hidden)

        output = F.log_softmax(self.out(output[0]), dim=1)
        return output, hidden, attn_weights

    def initHidden(self):
        
        if use_cuda:
            return self.hidden0.cuda()
        else:
            return self.hidden0

# %%
def train(lang, input_variable, target_variable, encoder, decoder, encoder_optimizer, decoder_optimizer,
          criterion, max_length=30, teacher_forcing_ratio = 0.5, bidirectional = False):
    
    encoder_hidden = encoder.initHidden()

    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()

    input_length = input_variable.size()[0]

    target_length = target_variable.size()[0]

    encoder_outputs = Variable(torch.zeros(max_length, encoder.hidden_size))
    encoder_outputs = encoder_outputs.cuda() if use_cuda else encoder_outputs

    loss = 0

    for ei in range(input_length):
        encoder_output, encoder_hidden = encoder(input_variable[ei], encoder_hidden)
        
        encoder_outputs[ei] = encoder_output[0][0]

    decoder_input = Variable(torch.LongTensor([[lang.SOS_token]]))
    decoder_input = decoder_input.cuda() if use_cuda else decoder_input
    
    if bidirectional:
        # sum the bidirectional hidden states into num_layers long cause the decoder is not bidirectional
        encoder_hidden = encoder_hidden[:encoder.num_layers, :, :] + encoder_hidden[encoder.num_layers:, : ,:] 
        
    decoder_hidden = encoder_hidden

    use_teacher_forcing = True if random.random() < teacher_forcing_ratio else False

    if use_teacher_forcing:
        # Teacher forcing: Feed the target as the next input
        for di in range(target_length):
            
            decoder_output, decoder_hidden, decoder_attention = decoder(
                decoder_input, decoder_hidden, encoder_outputs)
            
            loss += criterion(decoder_output, target_variable[di])
            decoder_input = target_variable[di]  # Teacher forcing

    else:
        # Without teacher forcing: use its own predictions as the next input
        for di in range(target_length):

            decoder_output, decoder_hidden, decoder_attention = decoder(
                decoder_input, decoder_hidden, encoder_outputs)
            
            topv, topi = decoder_output.data.topk(1)
            ni = topi[0][0]

            decoder_input = Variable(torch.LongTensor([[ni]]))
            decoder_input = decoder_input.cuda() if use_cuda else decoder_input

            loss += criterion(decoder_output, target_variable[di])
            if ni == lang.EOS_token:
                break

    loss.backward()

    encoder_optimizer.step()
    decoder_optimizer.step()

    return loss.data[0] / target_length

# %%
def trainIters(encoder, decoder, pairs, lang, n_iters =1000, print_every=100, plot_every=100,
               learning_rate=0.01, teacher_forcing_ratio = 0.5, bidirectional = False,
               name = "noname", lowest_loss =100, max_length = 30, gamma = 0.95, reverse=False):
    
    
    start = time.time()
    plot_losses = []
    print_loss_total = 0  # Reset every print_every
    plot_loss_total = 0  # Reset every plot_every
    
    encoder_optimizer = optim.Adam(encoder.parameters(), lr=learning_rate)
    decoder_optimizer = optim.Adam(decoder.parameters(), lr=learning_rate)
    #encoder_optimizer = optim.SGD(encoder.parameters(), lr=learning_rate)
    #decoder_optimizer = optim.SGD(decoder.parameters(), lr=learning_rate)
    
    escheduler = optim.lr_scheduler.StepLR(encoder_optimizer, step_size=print_every, gamma=gamma) 
    dscheduler = optim.lr_scheduler.StepLR(decoder_optimizer, step_size=print_every, gamma=gamma) 
    
    training_pairs = [variablesFromPair(random.choice(pairs),lang)
                      for i in range(n_iters)]
    
    criterion = nn.NLLLoss()

    lowest_loss = lowest_loss
    
    for iter in range(1, n_iters + 1):
        
        escheduler.step()
        dscheduler.step()
        
        training_pair = training_pairs[iter - 1]
        input_variable = training_pair[0]
        target_variable = training_pair[1]
        if reverse:
            input_variable = training_pair[1]
            target_variable = training_pair[0]

        loss = train(lang, input_variable, target_variable, encoder, decoder, 
                     encoder_optimizer, decoder_optimizer, criterion, 
                     teacher_forcing_ratio = teacher_forcing_ratio,
                     max_length = max_length, bidirectional =  bidirectional)
        
        print_loss_total += loss
        plot_loss_total += loss

        if iter % print_every == 0:
            print_loss_avg = print_loss_total / print_every
            print_loss_total = 0
            print('%s (%d %d%%) %.4f' % (timeSince(start, iter / n_iters),
                                         iter, iter / n_iters * 100, print_loss_avg))
            
            if lowest_loss > print_loss_avg:
                lowest_loss = print_loss_avg
                print("new lowest loss, saving...")
                torch.save(encoder.state_dict(), "saved_params/encoder"+name+".pth")
                torch.save(attn_decoder.state_dict(), "saved_params/attn_decoder"+name+".pth")

        if iter % plot_every == 0:
            plot_loss_avg = plot_loss_total / plot_every
            plot_losses.append(plot_loss_avg)
            plot_loss_total = 0


    showPlot(plot_losses)

# %%
hidden_size = 1024
num_layers = 2
bidirectional = True 

encoder = EncoderRNN(hidden_size, embedding, num_layers = num_layers, bidirectional = bidirectional,
                     train_embedding = True)


attn_decoder = AttnDecoderRNN(hidden_size,  embedding, dropout_p=0.1, num_layers = num_layers,
                               train_embedding = True, max_length = MAX_SENT_LENGTH)

if use_cuda:
    encoder = encoder.cuda()
    attn_decoder = attn_decoder.cuda()
    

version = 0
name = "hidden" + str(hidden_size) + "L" + str(num_layers) + "bidir"+str(bidirectional) + "v"+ str(version)

# %%
#encoder.load_state_dict(torch.load("saved_params/encoder"+name+".pth"))
#attn_decoder.load_state_dict(torch.load("saved_params/attn_decoder"+name+".pth"))
#name = "_256h_4L_bi_glove"
encoder.load_state_dict(torch.load("saved_params/encoder"+name+".pth"))
attn_decoder.load_state_dict(torch.load("saved_params/attn_decoder"+name+".pth"))

version = 3
name = "hidden" + str(hidden_size) + "L" + str(num_layers) + "bidir"+str(bidirectional) + "v"+ str(version)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-22-1d4b1b893876> in <module>()
#       2 #attn_decoder.load_state_dict(torch.load("saved_params/attn_decoder"+name+".pth"))
#       3 #name = "_256h_4L_bi_glove"
# ----> 4 encoder.load_state_dict(torch.load("saved_params/encoder"+name+".pth"))
#       5 attn_decoder.load_state_dict(torch.load("saved_params/attn_decoder"+name+".pth"))
#       6
#
# ~/.virtualenvs/py3/lib/python3.5/site-packages/torch/serialization.py in load(f, map_location, pickle_module)
#     263             (sys.version_info[0] == 3 and isinstance(f, pathlib.Path)):
#     264         new_fd = True
# --> 265         f = open(f, 'rb')
#     266     try:
#     267         return _load(f, map_location, pickle_module)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'saved_params/encoderhidden1024L2bidirTruev0.pth'

# %%
trainIters(encoder, attn_decoder, final_pairs, lang, n_iters = 100000, print_every=10000, 
           learning_rate=0.01, teacher_forcing_ratio = 0.99,
           bidirectional = bidirectional, name = name,
           max_length = MAX_SENT_LENGTH, lowest_loss = 4.0, gamma = 0.5)

# %%
#name = "_256h_4L_bi_glove"
torch.save(encoder.state_dict(), "saved_params/encoder"+name+".pth")
torch.save(attn_decoder.state_dict(), "saved_params/attn_decoder"+name+".pth")

# %%
# save cpu version

encoder.cpu()
attn_decoder.cpu()

torch.save(encoder.state_dict(), "saved_params/encoder"+name+"cpu.pth")
torch.save(attn_decoder.state_dict(), "saved_params/attn_decoder"+name+"cpu.pth")

# %%
evaluateRandomly(final_pairs, encoder, attn_decoder,  n=10, bidirectional = bidirectional)

evaluateAndShowAttention("hello",encoder, attn_decoder, bidirectional = bidirectional)

evaluateAndShowAttention("what link ?",encoder, attn_decoder, bidirectional = bidirectional)

evaluateAndShowAttention("why is this happening ?",encoder, attn_decoder, bidirectional = bidirectional)

evaluateAndShowAttention("tell me something stupid",encoder, attn_decoder, bidirectional = bidirectional)

evaluateAndShowAttention("you can make it if you try",encoder, attn_decoder, bidirectional = bidirectional)

evaluateAndShowAttention("where are we and where are we going ?",
                         encoder, attn_decoder, bidirectional = bidirectional  )
# Out:
# input from data > there is pastel bloc but it didnt catch on
# output from data= beige bloc could be a good look
# bot response < you are in the <UNK> <EOS>
#
# input from data > what the fuck are you doing here ?
# output from data= do you remember me ?
# bot response < you are <UNK> me <EOS>
#
# input from data > what specifically
# output from data= grunge classic rock hard rock alternative rock
# bot response < you are <UNK> me <EOS>
#
# input from data > gatorade
# output from data= what happened to all the gatorade ?
# bot response < you are <UNK> me <EOS>
#
# input from data > thanks autocorrect
# output from data= no i did it on purpose lol
# bot response < you are a <UNK> <UNK> <EOS>
#
# input from data > a most courteous exposition
# output from data= nay i am the very pink of courtesy
# bot response < you are a <UNK> <UNK> <EOS>
#
# input from data > huh ?
# output from data= so yvonnes gone over to the enemy
# bot response < you know what you said <EOS>
#
# input from data > thats right
# output from data= complicated or not life moves on hm ?
# bot response < you are <UNK> me <EOS>
#
# input from data > whenever hes got an edge on
# output from data= how often is that ?
# bot response < you are in the <UNK> <EOS>
#
# input from data > what ?
# output from data= did you hear what i said ?
# bot response < you are in the <UNK> <EOS>
#
# input = hello
# output = you are in the <UNK> <EOS>
# input = what link ?
# output = you are <UNK> me <EOS>
# input = why is this happening ?
# output = you know i was a <UNK> <EOS>
# input = tell me something stupid
# output = you are a <UNK> <EOS>
# input = you can make it if you try
# output = i dont think i should get a <UNK> <EOS>
# input = where are we and where are we going ?
# output = you are a <UNK> <EOS>

# %%
def evaluate(encoder, decoder, sentence, max_length=MAX_SENT_LENGTH,
             bidirectional =bidirectional):
    
    
    input_variable = variableFromSentence(lang, sentence)
    input_length = input_variable.size()[0]
    encoder_hidden = encoder.initHidden()

    encoder_outputs = Variable(torch.zeros(max_length, encoder.hidden_size))
    encoder_outputs = encoder_outputs.cuda() if use_cuda else encoder_outputs

    for ei in range(input_length):
        encoder_output, encoder_hidden = encoder(input_variable[ei],
                                                 encoder_hidden)
        encoder_outputs[ei] = encoder_outputs[ei] + encoder_output[0][0]

    decoder_input = Variable(torch.LongTensor([[lang.SOS_token]]))  # SOS
    decoder_input = decoder_input.cuda() if use_cuda else decoder_input
    
    if bidirectional:
        # sum the bidirectional hidden states into num_layers long cause the decoder is not bidirectional
        encoder_hidden = encoder_hidden[:encoder.num_layers, :, :] + encoder_hidden[encoder.num_layers:, : ,:]

    decoder_hidden = encoder_hidden

    decoded_words = []
    decoder_attentions = torch.zeros(max_length, max_length)

    for di in range(max_length):
        decoder_output, decoder_hidden, decoder_attention = decoder(
            decoder_input, decoder_hidden, encoder_outputs)
        decoder_attentions[di] = decoder_attention.data
        topv, topi = decoder_output.data.topk(1)
        ni = topi[0][0]
        if ni == lang.EOS_token:
            decoded_words.append('<EOS>')
            break
        else:
            decoded_words.append(lang.index2word[ni])

        decoder_input = Variable(torch.LongTensor([[ni]]))
        decoder_input = decoder_input.cuda() if use_cuda else decoder_input

    return decoded_words, decoder_attentions[:di + 1]

def evaluateRandomly(pairs, encoder, decoder, n=10, bidirectional = False):
    for i in range(n):
        pair = random.choice(pairs)
        print('input from data >', pair[0])
        print('output from data=', pair[1])
        output_words, attentions = evaluate(encoder, decoder, pair[0], bidirectional = bidirectional)
        output_sentence = ' '.join(output_words)
        print('bot response <', output_sentence)
        print('')
        
def showAttention(input_sentence, output_words, attentions, bidirectional = False):
    # Set up figure with colorbar
    fig = plt.figure()
    ax = fig.add_subplot(111)
    cax = ax.matshow(attentions.numpy(), cmap='bone')
    fig.colorbar(cax)

    # Set up axes
    ax.set_xticklabels([''] + input_sentence.split(' ') +
                       ['<EOS>'], rotation=90)
    ax.set_yticklabels([''] + output_words)

    # Show label at every tick
    ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
    ax.yaxis.set_major_locator(ticker.MultipleLocator(1))

    plt.show()


def evaluateAndShowAttention(input_sentence,encoder, attn_decoder, bidirectional = False):
    
    output_words, attentions = evaluate(encoder, attn_decoder, input_sentence, bidirectional = bidirectional)
    
    print('input =', input_sentence)
    print('output =', ' '.join(output_words))
    showAttention(input_sentence, output_words, attentions)

# %% [markdown]
# # Reinforcement Learning

# %% [markdown]
# ## Backward Seq2Seq

# %%
backward_encoder = EncoderRNN(hidden_size, num_layers = num_layers,
                              bidirectional = bidirectional, train_embedding=False)

backward_attn_decoder = AttnDecoderRNN(hidden_size, embedding, dropout_p=0.1, 
                                       num_layers = num_layers, train_embedding=False, max_length = MAX_SENT_LENGTH)

if use_cuda:
    backward_encoder = backward_encoder.cuda()
    backward_attn_decoder = backward_attn_decoder.cuda()

# %%
backward_encoder.load_state_dict(torch.load("saved_params/encoder_backward"+name+"cpu.pth"))
backward_attn_decoder.load_state_dict(torch.load("saved_params/attn_decoder_backward"+name+"cpu.pth"))

# %%
trainIters(backward_encoder, backward_attn_decoder, final_pairs, lang, n_iters = 100000, print_every=1000, 
           learning_rate=0.01, teacher_forcing_ratio = 1.0,
           bidirectional = bidirectional, name = '_backward' + name,
           lowest_loss = 6.0, gamma = 0.95, reverse=True)

# %%
torch.save(encoder.state_dict(), "saved_params/encoder_backward"+name+"cpu.pth")
torch.save(attn_decoder.state_dict(), "saved_params/attn_decoder_backward"+name+"cpu.pth")

# %% [markdown]
# ## The main training loops is trainRLIters(), it calls RLStep to get the forward loss, it calls calculate_rewards to get the rewards for each forward_loss element, the two are multiplied to ge the final loss as per REINFORCE. This final Loss is backpropagated

# %%
# Forward
forward_encoder = EncoderRNN(hidden_size, embedding, num_layers = num_layers, 
                             bidirectional = bidirectional, train_embedding = True)


forward_attn_decoder = AttnDecoderRNN(hidden_size,  embedding, dropout_p=0.1, 
                                      num_layers = num_layers, train_embedding = True, max_length = MAX_SENT_LENGTH)

# Backward
backward_encoder = EncoderRNN(hidden_size, num_layers = num_layers,
                              bidirectional = bidirectional, train_embedding=False)

backward_attn_decoder = AttnDecoderRNN(hidden_size, embedding, dropout_p=0.1, 
                                       num_layers = num_layers, train_embedding=False, max_length = MAX_SENT_LENGTH)

if use_cuda:
    forward_encoder = forward_encoder.cuda()
    forward_attn_decoder = forward_attn_decoder.cuda()
    
    backward_encoder = backward_encoder.cuda()
    backward_attn_decoder = backward_attn_decoder.cuda()

name = '_RL_' + name

# %%
forward_encoder.load_state_dict(torch.load("saved_params/encoder"+name+"cpu.pth"))
forward_attn_decoder.load_state_dict(torch.load("saved_params/attn_decoder"+name+"cpu.pth"))
backward_encoder.load_state_dict(torch.load("saved_params/encoder_backward"+name+"cpu.pth"))
backward_attn_decoder.load_state_dict(torch.load("saved_params/attn_decoder_backward"+name+"cpu.pth"))

# %%
def RLStep(lang, input_variable, target_variable, encoder, decoder, criterion, softmax, 
           max_length=30, teacher_forcing_ratio=0.5, bidirectional=False):
    
    encoder_hidden = encoder.initHidden()

    input_length = input_variable.size()[0]
    target_length = target_variable.size()[0]

    encoder_outputs = Variable(torch.zeros(max_length, encoder.hidden_size))
    encoder_outputs = encoder_outputs.cuda() if use_cuda else encoder_outputs

    loss = 0
    response = []
    
    for ei in range(input_length):
        
        encoder_output, encoder_hidden = encoder(input_variable[ei], encoder_hidden)
        
        encoder_outputs[ei] = encoder_output[0][0]

    decoder_input = Variable(torch.LongTensor([[lang.SOS_token]]))
    decoder_input = decoder_input.cuda() if use_cuda else decoder_input
    
    if bidirectional:
        # sum the bidirectional hidden states into num_layers long cause the decoder is not bidirectional
        encoder_hidden = encoder_hidden[:encoder.num_layers, :, :] + encoder_hidden[encoder.num_layers:, : ,:] 
        
    decoder_hidden = encoder_hidden

    use_teacher_forcing = True if random.random() < teacher_forcing_ratio else False

    if use_teacher_forcing:
        # Teacher forcing: Feed the target as the next input
        for di in range(target_length):
            
            decoder_output, decoder_hidden, decoder_attention = decoder(
                decoder_input, decoder_hidden, encoder_outputs)
            
            loss += criterion(softmax(decoder_output), target_variable[di])
            decoder_input = target_variable[di]  # Teacher forcing

    else:
        # Without teacher forcing: use its own predictions as the next input
        for di in range(target_length):

            decoder_output, decoder_hidden, decoder_attention = decoder(
                decoder_input, decoder_hidden, encoder_outputs)
            
            topv, topi = decoder_output.data.topk(1)
            ni = topi[0][0]

            decoder_input = Variable(torch.LongTensor([[ni]]))
            decoder_input = decoder_input.cuda() if use_cuda else decoder_input

            loss += criterion(softmax(decoder_output), target_variable[di])
            
            # TODO: ni or decoder_output?
            response.append(ni)
            if ni == lang.EOS_token:
                break
    # Cross entropy loss, target length, response
    return (loss, target_length, response)

# %%
def calculate_rewards(lang, input_variable, target_variable, curr_response,
                      forward_encoder, forward_decoder, 
                      backward_encoder, backward_decoder, 
                      criterion, softmax, dull_responses, 
                      teacher_forcing_ratio, bidirectional):
    ep_rewards = []
    
    # ep_num are used to bound the number of episodes
    # MAXIMUM ep = 10
    ep_num = 1
    
    responses = []
    
    ep_input = input_variable
    ep_target = target_variable
    
    ## At first, in trainRLIters, we already generated the 'first' curr_response. The loop below is to
    ## simulate one episode where two agents response back-to-back.
    while (ep_num <= 10):
        
        ## TODO: min length of response to break?
        
        ## Break once we see (1) dull response, (2) the response is less than 1, (3) repetition
        if (len(curr_response) < 1):# or (curr_response in responses) or (curr_response in dull_responses):
            break
            
        curr_response = Variable(torch.LongTensor(curr_response), requires_grad=False).view(-1, 1)
        curr_response = curr_response.cuda() if use_cuda else curr_response
        responses.append(curr_response)
        
        
        ## Ease of answering
        # Use the forward model to generate the log prob of generating dull response given ep_input.
        # Use the teacher_forcing_ratio = 1!
        r1 = 0
        for d in dull_responses:
            forward_loss, forward_len, _ = RLStep(lang, ep_input, d, 
                                                  forward_encoder, forward_decoder, 
                                                  criterion, softmax, 
                                                  teacher_forcing_ratio = 1.1,
                                                  bidirectional =  bidirectional)
            if forward_len > 0:
                # log (1/P(a|s)) = CE  --> log(P(a | s)) = - CE
                r1 -= forward_loss / forward_len
        if len(dull_responses) > 0:
            r1 = r1 / len(dull_responses)
    
    
        ## Information flow
        # responses contains all the generated response by the forward model
        r2 = 0
        if (len(responses) > 2):
            # vec_a --> h_(i)  = responses[-3]
            # vec_b --> h_(i+1)= responses[-1]
            vec_a = responses[-3].data
            vec_b = responses[-1].data
            # length of the two vector might not match
            min_length = min(len(vec_a), len(vec_b))
            vec_a = vec_a[:min_length]
            vec_b = vec_b[:min_length]
            cos_sim = 1 - scipy.spatial.distance.cosine(vec_a, vec_b)
            # -1 <= cos_sim <= 1
            # TODO: how to handle negative cos_sim?
            if cos_sim <= 0:
                r2 = - cos_sim
            else:
                r2 = - np.log(cos_sim)
            
        
        
        ## Semantic Coherence
        # Use the forward model to generate the log prob of generating curr_response given ep_input
        # Use the backward model to generate the log prob of generating ep_input given curr_response
        r3 = 0
        forward_loss, forward_len, _ = RLStep(lang, ep_input, curr_response, 
                                              forward_encoder, forward_decoder, 
                                              criterion, softmax,
                                              teacher_forcing_ratio = teacher_forcing_ratio,
                                              bidirectional =  bidirectional)
        backward_loss, backward_len, _ = RLStep(lang, curr_response, ep_input, 
                                                backward_encoder, backward_decoder, 
                                                criterion, softmax,
                                                teacher_forcing_ratio = teacher_forcing_ratio,
                                                bidirectional =  bidirectional)
        
        ## Loss is negative log probability
        if forward_len > 0:
            r3 += (-1. * forward_loss) / forward_len
        if backward_len > 0:
            r3 += (-1. * backward_loss) / backward_len
            
            
        ## Add up all the three rewards
        rewards = 0.25 * r1 + 0.25 * r2 + 0.5 * r3
        ep_rewards.append(rewards)
        
        ## Set the next input
        ep_input = curr_response
        ## TODO: what's the limit of the length? and what should we put as the dummy target?
        ep_target = Variable(torch.LongTensor([0] * 30), requires_grad=False).view(-1, 1)
        ep_target = ep_target.cuda() if use_cuda else ep_target
        
        # Turn off the teacher forcing ration after first iteration (since we don't have a target anymore).
        teacher_forcing_ratio = 0
        ep_num += 1
        
        # First start with Forward model to generate the current response, given ep_input
        # ep_target is empty if ep_num > 1
        _, _, curr_response = RLStep(lang, ep_input, ep_target, 
                                     forward_encoder, forward_decoder, 
                                     criterion, softmax,
                                     teacher_forcing_ratio = teacher_forcing_ratio,
                                     bidirectional =  bidirectional)

    # Take the mean of the episodic rewards
    r = 0
    if len(ep_rewards) > 0:
        r = np.mean(ep_rewards)
    else:
        ## TODO: what to do when overall reward = 0?
        r = 1
    return r

# %%
def trainRLIters(forward_encoder, forward_decoder, backward_encoder, backward_decoder,
                 pairs, lang, dull_responses, 
                 n_iters =1000, print_every=100, plot_every=100, 
                 learning_rate=0.01, teacher_forcing_ratio = 0.5, bidirectional = False, 
                 name = "noname", lowest_loss =100, gamma = 0.95):
    
    
    start = time.time()
    plot_losses = []
    print_loss_total = 0  # Reset every print_every
    plot_loss_total = 0  # Reset every plot_every
    
    # Optimizer
    forward_encoder_optimizer = optim.Adam(forward_encoder.parameters(), lr=learning_rate)
    forward_decoder_optimizer = optim.Adam(forward_decoder.parameters(), lr=learning_rate)
    
    # Scheduler
    forward_escheduler = optim.lr_scheduler.StepLR(forward_encoder_optimizer, step_size=print_every, gamma=gamma) 
    forward_dscheduler = optim.lr_scheduler.StepLR(forward_decoder_optimizer, step_size=print_every, gamma=gamma) 
    
    training_pairs = [variablesFromPair(random.choice(pairs),lang)
                      for i in range(n_iters)]
    
    criterion = nn.NLLLoss()
    softmax = nn.LogSoftmax()
    
    lowest_loss = lowest_loss
    
    for iter in range(1, n_iters + 1):
        
        forward_escheduler.step()
        forward_dscheduler.step()
        
        training_pair = training_pairs[iter - 1]
        input_variable = training_pair[0]
        target_variable = training_pair[1]
        
        ## Manually zero out the optimizer
        forward_encoder_optimizer.zero_grad()
        forward_decoder_optimizer.zero_grad()
        
        ## Do one forward step.
        forward_loss, forward_len, forward_response = RLStep(lang, input_variable, target_variable, 
                                                             forward_encoder, forward_decoder, 
                                                             criterion, softmax,
                                                             teacher_forcing_ratio = teacher_forcing_ratio,
                                                             bidirectional =  bidirectional)
        
        ## Calculate the reward
        reward = calculate_rewards(lang, input_variable, target_variable, forward_response,
                                   forward_encoder, forward_decoder, 
                                   backward_encoder, backward_decoder, 
                                   criterion, softmax, dull_responses, 
                                   teacher_forcing_ratio, bidirectional)
        
        ## Update the forward seq2seq with its loss scaled by the reward
        loss = forward_loss * reward
        
        loss.backward()
        forward_encoder_optimizer.step()
        forward_decoder_optimizer.step()
        
        print_loss_total += (loss.data[0] / forward_len)
        plot_loss_total += (loss.data[0] / forward_len)

        if iter % print_every == 0:
            print_loss_avg = print_loss_total / print_every
            print_loss_total = 0
            print('%s (%d %d%%) %.4f' % (timeSince(start, iter / n_iters),
                                         iter, iter / n_iters * 100, print_loss_avg))
            
            if lowest_loss > print_loss_avg:
                lowest_loss = print_loss_avg
                print("new lowest loss, saving...")
                torch.save(encoder.state_dict(), "saved_params/encoder"+name+".pth")
                torch.save(attn_decoder.state_dict(), "saved_params/attn_decoder"+name+".pth")

        if iter % plot_every == 0:
            plot_loss_avg = plot_loss_total / plot_every
            plot_losses.append(plot_loss_avg)
            plot_loss_total = 0


    showPlot(plot_losses)

# %% [markdown]
# ### Initialize dull_responses as a list of Variables

# %%
# TODO
dull_responses = []

# %%
trainRLIters(forward_encoder, forward_attn_decoder, backward_encoder, backward_attn_decoder, 
             final_pairs, lang, dull_responses,
             n_iters=100000, print_every=1000, learning_rate=0.01, 
             teacher_forcing_ratio = 0.75, bidirectional = bidirectional, name = name, lowest_loss=6.0, gamma = 0.95)

# %%
torch.save(encoder.state_dict(), "saved_params/encoder"+name+"cpu.pth")
torch.save(attn_decoder.state_dict(), "saved_params/attn_decoder"+name+"cpu.pth")

# %%
evaluateRandomly(forward_encoder, forward_attn_decoder,  n=10, bidirectional = bidirectional)
